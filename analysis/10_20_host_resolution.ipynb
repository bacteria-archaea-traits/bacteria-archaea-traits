# %%
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
import matplotlib.pyplot as plt
import seaborn as sns
import re
from itertools import islice
from collections import Counter
import networkx as nx

# %%
taxonomy_lineage = pd.read_csv("../output/ranked_lineage.tsv", sep='\t')

# %%
pattern = re.compile(r'Eukaryota', flags=re.IGNORECASE)
taxonomy_lineage_eukaryota =  taxonomy_lineage[taxonomy_lineage['Lineage'].str.match(pattern, na=False)]

# %%
def process_row(row):
    taxonomy_path = row.Lineage.strip().split('>')
    
    current_dict = nested_dict
    for category in taxonomy_path:
        if category not in current_dict:
            current_dict[category] = {}
        current_dict = current_dict[category]

def get_values_count_per_level(nested_dict, max_level, level=1):
    global level_count_dict
    specific_level_value_count = get_specific_level_nested_dict(nested_dict, max_level, level)
    return specific_level_value_count
def get_specific_level_nested_dict(nested_dict, max_level, specific_explore=""):
    level_count_dict = {}
    stack = [(key, value, 1) for key, value in nested_dict.items()]
    while stack:
        key, value, level = stack.pop()
        if isinstance(value, dict):
            if level == max_level:
                if specific_explore != "":
                    if key == specific_explore:
                        level_count_dict = value
                        break
                else:
                    if value:
                        level_count_dict[key] = len(value)
            stack.extend((k, v, level + 1) for k, v in value.items())
    return level_count_dict

def batched(iterable, n):
        if n < 1:
            raise ValueError('n must be at least one')
        it = iter(iterable)
        while batch := tuple(islice(it, n)):
            yield batch
            
def long_data(level_count_dict):
    level_data_frame = pd.DataFrame(columns = ["level", "count", "facet"])
    for idx, batch in enumerate(batched(level_count_dict.items(), 10)):
        batched_data = pd.DataFrame(batch)
        batched_data["facet"] = idx
        batched_data.columns = ["level", "count", "facet"]
        level_data_frame = pd.concat([level_data_frame, batched_data])
    return level_data_frame

def visualize_levels(nested_dict, max_level, amount_each_facet = 15):
    specific_level_value_count = get_specific_level_nested_dict(nested_dict, max_level)
    long_level_data = long_data(specific_level_value_count)
    #sns.FacetGrid(long_level_data, col="facet", sharey=True, )
    category_order = [x for x, y in sorted(specific_level_value_count.items(), key=lambda x: x[1], reverse=True)]
    barplot = sns.barplot(x=specific_level_value_count.keys(), y = specific_level_value_count.values(), 
            order = category_order)
    barplot.set_xticklabels(category_order, rotation=90)
 
from multiprocessing import Manager

def get_species_tax_name_lineage(species_name, taxonomy_lineage_eukaryota):
    pattern = re.compile(species_name, flags=re.IGNORECASE)
    w = taxonomy_lineage_eukaryota[taxonomy_lineage_eukaryota['tax_name'].str.match(pattern, na=False)]
    if w.shape[0] <= 0: 
        print(f"Species {species_name} not matched")
    return w

# %%
nested_dict = {}
with ThreadPoolExecutor(max_workers=None) as executor:
    print(executor._max_workers)
    executor.map(process_row, taxonomy_lineage_eukaryota.itertuples(index=False))
linearage_nested_dict = nested_dict
# Out:
# 8

# %%
from multiprocessing import Manager

liamp_shaw = pd.read_csv("../data/raw/liamp-shaw/PathogenVsHostDB-2019-05-30.csv", encoding="latin-1")
liamp_shaw_host = liamp_shaw[["HostGroup", "HostOrder", "HostFamily", "HostSpecies", "HostName"]]
liamp_shaw_host.columns =["phylum", "order", "family", "species", "name"]

host_species_resolutions = pd.DataFrame(columns=list(taxonomy_lineage.columns))
liamp_shaw_host = liamp_shaw[["HostGroup", "HostOrder", "HostFamily", "HostSpecies", "HostName"]]
liamp_shaw_host.columns =["phylum", "order", "family", "species", "name"]
species_names = pd.DataFrame(liamp_shaw_host.species.unique())
with Manager() as manager: 
    shared_data = manager.list([taxonomy_lineage_eukaryota, host_species_resolutions])
    with ThreadPoolExecutor(max_workers=None) as executor:
        executor.map(get_species_tax_name_lineage, 
                     species_names.itertuples(index=False), 
                     [shared_data] * len(species_names))

# %%
host_species_resolutions = pd.DataFrame(columns=list(taxonomy_lineage.columns))
for species_name in liamp_shaw_host.species.unique():
    w = get_species_tax_name_lineage(species_name, taxonomy_lineage_eukaryota)
    if w.shape[0] > 0:
        host_species_resolutions = pd.concat([host_species_resolutions, w])
host_species_resolutions.to_csv("lineage_liamp_shaw.csv")
# Out:
# Species Ovis aries orientalis not matched
# Species Neovison vison not matched
# Species Spermophilus richardsonii not matched
# Species Gyps rueppellii not matched
# Species Anas cyanoptera not matched
# Species Grus canadensis not matched
# Species Uncia uncia not matched
# Species Otaria flavescens not matched
# Species Astronotus ocellatus  not matched
# Species Symphysodon aequifasciatus not matched
# Species Rhacophorus arboreus not matched
# Species Acrocodia indica not matched
# Species Epinephelus septemfasciatus not matched
# Species Spermophilus columbianus not matched
# Species Chelidonichthys lucernus not matched
# Species Litoria citropa not matched
# Species Philomachus pugnax not matched
# Species Puffinus tenuirostris not matched
# Species Pionopsitta barrabandi not matched
# Species Pagophilus groenlandicus not matched
# Species Puntius conchonius not matched
# Species Liza klunzingeri not matched
# Species Dasyatis fluviorum not matched
# Species Himantura granulata not matched
# Species Liza alata not matched
# Species Chromileptes altivelis not matched
# Species Anas clypeata not matched
# Species Chen rossii not matched
# Species Chelonoidis carbonaria not matched
# Species Sus salvanius not matched
# Species Chen caerulescens not matched
# Species Aratinga pertinax not matched
# Species Macropus rufogriseus not matched
# Species Callicebus caligatus not matched
# Species Myodes gapperi not matched
# Species Spermophilus beecheyi not matched
# Species Litoria caerulea not matched
# Species Sciurus griseus not matched
# Species Picoides pubescens not matched
# Species Spermophilus lateralis not matched
# Species Macropus agilis not matched
# Species Anas americana not matched
# Species Anas strepera not matched
# Species Gibelion catla not matched
# Species Epinephelus quoyanus not matched
# Species Rhipidura fulginosa not matched
# Species Sylvia communis not matched
# Species Chamaeleo ellioti not matched
# Species Elaphe guttata not matched
# Species Egretta intermedia not matched
# Species Pangasius hypophthalmus not matched
# Species Dentex tumifrons not matched
# Species Spodiopsar cineraceus not matched
# Species Martes pennanti not matched
# Species Mustela eversmanii not matched
# Species Allactaga sibirica not matched
# Species Spermophilus parryii not matched
# Species Macropus rufus not matched
# Species Orthriophis moellendorffi not matched
# Species Leiopython albertisi not matched
# Species Pseudepidalea viridis not matched
# Species Equus africanus not matched
# Species Cyprinus carpio koi not matched
# Species Gallus gallus domesticus not matched
# Species Amazona xanthops not matched
# Species Aratinga aurea not matched
# Species Aratinga canicularis not matched
# Species Aratinga erythrogenys not matched
# Species Aratinga leucophthalma not matched
# Species Cephalophus rufilatus not matched
# Species Damaliscus korrigum not matched
# Species Mazama gouazoubira not matched
# Species Anas penelope not matched
# Species Equus africanus somaliensis not matched
# Species Macropus parma not matched
# Species Macropus robustus not matched
# Species Dorcopsis muelleri not matched
# Species Emys marmorata not matched
# Species Histriophoca fasciata not matched
# Species Piliocolobus semlikiensis not matched
# Species Micropteropus pusillus not matched
# Species Anas querquedula not matched
# Species Chen canagica not matched
# Species Anthropoides virgo not matched
# Species Nandayus nenday not matched
# Species Pitta guajana not matched
# Species Anas discors not matched
# Species Anas formosa not matched
# Species Streptopelia senegalensis not matched
# Species Grus antigone not matched
# Species Dobsonia anderseni not matched
# Species Physeter macrocephalus not matched
# Species Nycteris gambiensis not matched
# Species Hipposideros commersonii not matched
# Species Leopardus colocolo not matched
# Species Herpestes javanicus not matched
# Species Dermanura phaeotis not matched
# Species Lasiurus cinereus not matched
# Species Lasiurus ega not matched
# Species Lasiurus egregius not matched
# Species Lasiurus intermedius not matched
# Species Lasiurus xanthinus not matched
# Species Erethizon dorsatus not matched
# Species Theragra chalcogramma not matched
# Species Caprimulgus carolinensis not matched
# Species Coendou rothschildi not matched
# Species Hipposideros crumeniferus not matched
# Species Eurynorhynchus pygmeus not matched
# Species Puffinus pacificus not matched
# Species Saguinus fuscicollis not matched
# Species Saguinus nigricollis not matched
# Species Microtus levis not matched
# Species Puffinus carneipes not matched
# Species Microtus gregalis not matched
# Species Meriones hurrianae not matched
# Species Gerbilliscus kempii not matched
# Species Sylvia curruca not matched
# Species Cisticola chiniana not matched
# Species Monachus schauinslandi not matched
# Species Aratinga finschi not matched
# Species Cacatua leadbeateri not matched
# Species Calyptorhynchus funereus not matched
# Species Glossopsitta porphyrocephala not matched
# Species Dermanura cinerea not matched
# Species Micoureus demerarae not matched
# Species Macropus parryi not matched
# Species Miniopterus schreibersii fuliginosus not matched
# Species Madromys blanfordi not matched
# Species Alouatta nigerrima not matched
# Species Luscinia calliope not matched
# Species Crocidura zaphiri not matched
# Species Eliomys munbyanus not matched
# Species Lophocebus johnstoni not matched
# Species Oncorhynchus aguabonita not matched
# Species Oncorhynchus apache not matched
# Species Parambassis baculis not matched
# Species Secutor insidiator not matched
# Species Litoria brevipes not matched
# Species Litoria alboguttata not matched
# Species Hyla chrysoscelis not matched
# Species Japalura splendida not matched
# Species Hyla japonica not matched
# Species Hyla versicolor not matched
# Species Scinax elaeochrous not matched
# Species Cochranella spinosa not matched
# Species Labroides dimidatus not matched
# Species Monocentris japonica not matched
# Species Callionymus lunatus not matched
# Species Takifugu niphobles not matched
# Species Francolinus leucoscepus not matched
# Species Pterocnemia pennata not matched
# Species Aratinga acuticaudata not matched
# Species Funisciurus congicus not matched
# Species Funisciurus lemniscatus not matched
# Species Cephalophus niger not matched
# Species Cephalophus zebra not matched
# Species Orthriophis taeniurus not matched
# Species Sapajus robustus not matched
# Species Hyla cinerea not matched
# Species Sphiggurus melanurus not matched
# Species Macropus dorsalis not matched
# Species Oryzomys alfaroi not matched
# Species Sphiggurus mexicanus not matched
# Species Liomys salvini not matched

# %%
host_species_resolutions = pd.read_csv("lineage_liamp_shaw.csv")
insect_host_species_resolutions = pd.read_csv("insect_host_lineage.csv")
liamp_shaw = pd.read_csv("../data/raw/liamp-shaw/PathogenVsHostDB-2019-05-30.csv", encoding="latin-1")
liamp_shaw_host = liamp_shaw[["HostGroup", "HostOrder", "HostFamily", "HostSpecies", "HostName"]]
liamp_shaw_host.columns =["phylum", "order", "family", "species", "name"]
species_names = pd.DataFrame(liamp_shaw_host.species.unique())

# %%
insect_host_species_resolutions = pd.DataFrame(columns=list(taxonomy_lineage.columns))
insect_pathogens_host = pd.read_csv("insect_interactions_pathogen_host.csv")
for species_name in insect_pathogens_host.sourceTaxonName.unique():
    w = get_species_tax_name_lineage(species_name, taxonomy_lineage_eukaryota)
    if w.shape[0] > 0:
        insect_host_species_resolutions = pd.concat([insect_host_species_resolutions, w])
# Out:
# Species Aphodius tasmaniae not matched
# Species Rhizotrogus majalis not matched
# Species Anoplognathus hirsutus not matched
# Species Oryctes monoceros not matched
# Species Antitrogus morbillosus not matched
# Species Othnonius batesi not matched
# Species Rhopaea verreauxi not matched
# Species Maladera brunnea not matched
# Species Rhizotrogus solstitiale not matched
# Species Sericesthis germinata not matched
# Species Sericesthis ocularis not matched
# Species Nematus ribesii not matched
# Species Pseudaletia unipuncta not matched
# Species Sabulodes aegrotata not matched
# Species Pericoptus truncatus not matched
# Species Gremifania nigrocellulata not matched
# Species Cleonus punctiventris not matched
# Species Phyllophaga smithi not matched
# Species Strategus antaeus not matched
# Species Lixophaga diatraeae not matched
# Species Liohippelates collusor not matched
# Species Locustana pardalina not matched
# Species Epilachna vigintioctomaculata not matched
# Species Carposina niponensis not matched
# Species Metaseiulus occidentalis not matched
# Species Trichiocampus irregularis not matched
# Species Pikonema alaskensis not matched
# Species Eremobothynus cornutus not matched
# Species Amphimallon solstitialis not matched
# Species Blitopertha orientalis not matched
# Species Pyronota festiva not matched
# Species Archips crataegana not matched
# Species Choristoneura crataegana not matched

# %%
import numpy as np

unique_host_resolutions = pd.concat([insect_host_species_resolutions, 
                               host_species_resolutions[[species_name in np.array(species_names) for species_name in host_species_resolutions.tax_name]]])
nested_dict = {}
with ThreadPoolExecutor(max_workers=None) as executor:
    print(executor._max_workers)
    executor.map(process_row, unique_host_resolutions.itertuples(index=False))
condensed_species_nested_dict = nested_dict
# Out:
# 8

# %%
def get_cytoscape_elements(tree_subset):
    elements = []
    stack = [(key, value) for key, value in tree_subset.items()]
    while stack:
        key, values = stack.pop(0)
        elements.append({'data': {'id': key}})
        if isinstance(values, dict):
            for k_ in values.keys():
                elements.append({'data': {'source': key, 'target': k_, 'weight': len(values[k_])}})   
            stack.extend([(k, v) for k, v in values.items()])
    return elements

elements = get_cytoscape_elements(condensed_species_nested_dict)

# %%
import concurrent.futures

def process_element(key, values, elements, stack):
    data = [{'data': {'id': key}}]
    if isinstance(values, dict):
        for k_, v_ in values.items():
            data.append({'data': {'source': key, 'target': k_, 'weight': len(v_)}})
        stack.extend([(key, value) for key, value in values.items()])
    elements.extend(data)
def get_cytoscape_elements(tree_subset):
    elements = []
    stack = [(key, value) for key, value in tree_subset.items()]
    with concurrent.futures.ThreadPoolExecutor() as executor:
        while stack:
            key, values = stack.pop(0)
            executor.submit(process_element, key, values, elements, stack)
    return elements

elements = get_cytoscape_elements(condensed_species_nested_dict)
print(elements)
# Out:
# [{'data': {'id': 'Eukaryota'}}, {'data': {'source': 'Eukaryota', 'target': 'Arthropoda', 'weight': 2}}, {'data': {'source': 'Eukaryota', 'target': 'Ascomycota', 'weight': 0}}, {'data': {'source': 'Eukaryota', 'target': 'Chordata', 'weight': 7}}, {'data': {'id': 'Arthropoda'}}, {'data': {'source': 'Arthropoda', 'target': 'Insecta', 'weight': 7}}, {'data': {'source': 'Arthropoda', 'target': 'Arachnida', 'weight': 1}}, {'data': {'id': 'Ascomycota'}}, {'data': {'id': 'Chordata'}}, {'data': {'source': 'Chordata', 'target': 'Mammalia', 'weight': 20}}, {'data': {'source': 'Chordata', 'target': 'Lepidosauria', 'weight': 1}}, {'data': {'source': 'Chordata', 'target': 'Aves', 'weight': 32}}, {'data': {'source': 'Chordata', 'target': 'Actinopteri', 'weight': 42}}, {'data': {'source': 'Chordata', 'target': 'Amphibia', 'weight': 2}}, {'data': {'source': 'Chordata', 'target': 'Hyperoartia', 'weight': 1}}, {'data': {'source': 'Chordata', 'target': 'Chondrichthyes', 'weight': 6}}, {'data': {'id': 'Insecta'}}, {'data': {'source': 'Insecta', 'target': 'Coleoptera', 'weight': 6}}, {'data': {'source': 'Insecta', 'target': 'Orthoptera', 'weight': 1}}, {'data': {'source': 'Insecta', 'target': 'Lepidoptera', 'weight': 14}}, {'data': {'source': 'Insecta', 'target': 'Hemiptera', 'weight': 2}}, {'data': {'source': 'Insecta', 'target': 'Diptera', 'weight': 5}}, {'data': {'source': 'Insecta', 'target': 'Hymenoptera', 'weight': 6}}, {'data': {'source': 'Insecta', 'target': 'Blattodea', 'weight': 3}}, {'data': {'id': 'Arachnida'}}, {'data': {'source': 'Arachnida', 'target': 'Ixodida', 'weight': 1}}, {'data': {'id': 'Mammalia'}}, {'data': {'source': 'Mammalia', 'target': 'Primates', 'weight': 13}}, {'data': {'source': 'Mammalia', 'target': 'Artiodactyla', 'weight': 19}}, {'data': {'source': 'Mammalia', 'target': 'Carnivora', 'weight': 14}}, {'data': {'source': 'Mammalia', 'target': 'Perissodactyla', 'weight': 3}}, {'data': {'source': 'Mammalia', 'target': 'Rodentia', 'weight': 21}}, {'data': {'source': 'Mammalia', 'target': 'Lagomorpha', 'weight': 2}}, {'data': {'source': 'Mammalia', 'target': 'Proboscidea', 'weight': 1}}, {'data': {'source': 'Mammalia', 'target': 'Eulipotyphla', 'weight': 3}}, {'data': {'source': 'Mammalia', 'target': 'Cingulata', 'weight': 2}}, {'data': {'source': 'Mammalia', 'target': 'Didelphimorphia', 'weight': 1}}, {'data': {'source': 'Mammalia', 'target': 'Diprotodontia', 'weight': 7}}, {'data': {'source': 'Mammalia', 'target': 'Dasyuromorphia', 'weight': 2}}, {'data': {'source': 'Mammalia', 'target': 'Sirenia', 'weight': 1}}, {'data': {'source': 'Mammalia', 'target': 'Hyracoidea', 'weight': 1}}, {'data': {'source': 'Mammalia', 'target': 'Peramelemorphia', 'weight': 1}}, {'data': {'source': 'Mammalia', 'target': 'Chiroptera', 'weight': 11}}, {'data': {'source': 'Mammalia', 'target': 'Macroscelidea', 'weight': 1}}, {'data': {'source': 'Mammalia', 'target': 'Pilosa', 'weight': 4}}, {'data': {'source': 'Mammalia', 'target': 'Monotremata', 'weight': 1}}, {'data': {'source': 'Mammalia', 'target': 'Scandentia', 'weight': 1}}, {'data': {'id': 'Lepidosauria'}}, {'data': {'source': 'Lepidosauria', 'target': 'Squamata', 'weight': 21}}, {'data': {'id': 'Aves'}}, {'data': {'source': 'Aves', 'target': 'Columbiformes', 'weight': 1}}, {'data': {'source': 'Aves', 'target': 'Galliformes', 'weight': 4}}, {'data': {'source': 'Aves', 'target': 'Ciconiiformes', 'weight': 1}}, {'data': {'source': 'Aves', 'target': 'Accipitriformes', 'weight': 4}}, {'data': {'source': 'Aves', 'target': 'Charadriiformes', 'weight': 10}}, {'data': {'source': 'Aves', 'target': 'Psittaciformes', 'weight': 3}}, {'data': {'source': 'Aves', 'target': 'Sphenisciformes', 'weight': 1}}, {'data': {'source': 'Aves', 'target': 'Anseriformes', 'weight': 2}}, {'data': {'source': 'Aves', 'target': 'Casuariiformes', 'weight': 1}}, {'data': {'source': 'Aves', 'target': 'Coraciiformes', 'weight': 2}}, {'data': {'source': 'Aves', 'target': 'Falconiformes', 'weight': 1}}, {'data': {'source': ' ...

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.graph_objs as go

import dash_cytoscape as cyto

condensed_species_nested_cytoscape_graph_elements = elements
app = dash.Dash(
    __name__,
    meta_tags=[
        {
            "name": "viewport",
            "content": "width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no",
        }
    ],
)

levels_defined = {
    "superkingdom":1,
    "phylum":2,
    "class":3,
    "order":4,
    "family":5,
    "genus":6,
    "species":7
}

reverse_mapping = {value: key for key, value in levels_defined.items()}

levels_list = list(levels_defined.keys())

def load_data(max_level, level, linearage_nested_dict, level_count_dict ={}):
    data = get_specific_level_nested_dict(linearage_nested_dict, max_level=level)
    return data

def get_subtree_level_stats(subtree_dictionary):
    level_count_dict = {}
    stack = [(subtree_dictionary, 0)] 
    while stack:
        current_dict, level = stack.pop()
        level_count = level_count_dict.get(level, 1) 
        level_count += len(current_dict)
        level_count_dict[level] = level_count

        for sub_dict in current_dict.values():
            if isinstance(sub_dict, dict):
                stack.append((sub_dict, level + 1))

    return level_count_dict


data = load_data(max_level = 1, level = 1, linearage_nested_dict=linearage_nested_dict)
host_data = load_data(max_level = 1, level = 1, linearage_nested_dict=condensed_species_nested_dict)
def build_upper_left_panel():
    return html.Div(
        id="upper-left",
        className="six columns",
        children=[
            html.P(
                className="section-title",
                children="Select the phylum levels for the taxonomy visualization",
            ),
            html.Div(
                className="control-row-1",
                children=[
                    html.Div(
                        id="state-select-outer",
                        children=[
                            html.Label("Select a taxonomoy level"),
                            dcc.Dropdown(
                                id="select_taxonomy_level",
                                options=[{"label": i, "value": i} for i in levels_list],
                                value=levels_list[0],
                            ),
                        ],
                    )
                ],
            )
        ],
    )

app.layout =html.Div(
    className="container scalable",
    children=[
        html.Div(
            id="banner",
            className="banner",
            children=[
                html.H6("Taxonomy visualization")
            ],
        ), 
        html.Div(
            id="upper_cointainer", 
            children = [
                build_upper_left_panel(),
                html.Div(
                    id="visualize levels informations. ",
                    children = [
                       html.Label("Select Level:"), 
                       dcc.Dropdown(
                            multi=True, 
                            searchable=True,
                            id='level-dropdown')
                    ],
                ), 
                dcc.Graph(id='nested-plot')
            ]),
        html.Div(
            id='level_exploir',
            children = [
                dcc.Dropdown(
                    id="specific-level-explorer-dropdown",
                    options=[{"label": i, "value": i} for i in ['Mammalia', 'Insecta']],
                    value='Mammalia',
                    style={'width': '50%'}
                ), 
                dcc.Dropdown(
                    id="add_level", 
                    options = [{"label":"","value":""}], 
                    value= "",
                    style={'width': '50%'}
                )], style={'display': 'flex', 'flexDirection': 'row'}),
        html.Div(
            children = [
            dcc.Graph(id='nested-plot-1'),
            cyto.Cytoscape(
                id='cytoscape-graph',
                layout={'name': 'cose'},
                style={'width': '50%', 'height': '400px'},
                elements={},
                stylesheet=[
                    {
                        'selector': 'node',
                        'style': {
                            'label': 'data(id)'
                        }
                    }
                ]
            )
        ], style={'display': 'flex', 'flexDirection': 'row'})
    ])
@app.callback(
    Output('nested-plot', 'figure'),
    Input('level-dropdown', 'value'),
    Input('select_taxonomy_level', 'value')
)
def update_plot(selected_level, select_taxonomy_level):
    keys = [key for key in selected_level]
    values = [data[key] for key in keys]

    host_keys = [k for k in keys if k in host_data.keys()]
    host_values = [host_data[key] for key in host_keys]
    fig = go.Figure(data=[
        go.Bar(name="Taxonomy lineage", x=keys, y=values), 
        go.Bar(name="host data", x=host_keys, y=host_values)
        ])
    fig.update_layout(title=f"Plot visualization for {select_taxonomy_level} level: ")
    return fig

@app.callback(
    [
        Output("level-dropdown", "value"),
        Output("level-dropdown", "options"), 
        Output('specific-level-explorer-dropdown', 'value'), 
        Output('specific-level-explorer-dropdown', 'options')
    ],
    Input('select_taxonomy_level', 'value')
)
def select_data_by_levels(select_taxonomy_level):
    level = levels_defined.get(select_taxonomy_level)
    global data
    global host_data
    data = get_specific_level_nested_dict(linearage_nested_dict  , max_level=level)
    host_data = get_specific_level_nested_dict(condensed_species_nested_dict  , max_level=level)
    options = [{"label": i, "value": i} for i in data.keys()]
    values = [i["value"] for i in options ]

    return ( values, options, values, options)

@app.callback(
    Output('level-dropdown', 'style'),
    Input('nested-plot', 'clickData') 
)
def update_dropdown_visibility(click_data):
    return {'display': 'flex'}

@app.callback(
    Output('nested-plot-1', 'figure'),
    Input('select_taxonomy_level', 'value'), 
    Input('specific-level-explorer-dropdown', 'value'),
)
def update_nested_plot(select_taxonomy_level, specific_level_explore):
    select_taxonomy_map_no = levels_defined.get(select_taxonomy_level)
    tree_subset = get_specific_level_nested_dict(linearage_nested_dict, max_level=select_taxonomy_map_no, 
                                                 specific_explore=specific_level_explore)
    subtree_level_stats = get_subtree_level_stats(tree_subset)
    subtree_level_stats = { reverse_mapping.get(k+1+select_taxonomy_map_no): v for k, v in subtree_level_stats.items()}
    fig = go.Figure(data=[go.Bar(x=list(subtree_level_stats.keys()), y=list(subtree_level_stats.values()))])
    fig.update_layout(title=f"Plot visualization for {specific_level_explore} level: ")
    return fig

@app.callback(
    Output('cytoscape-graph', 'elements'),
    Output('add_level', 'value'), 
    Output('add_level', 'options'),
    Input('cytoscape-graph', 'elements'),
    Input('specific-level-explorer-dropdown', 'value'), 
    Input('add_level', 'value'))
def update_elements(elements, specific_level_explore, add_level_value):
    targets = [specific_level_explore]
    subgraphs = []
    if isinstance(add_level_value, str):
        targets = [add_level_value]

    for target in targets: 
        subgraphs.extend(get_all_the_subsets(condensed_species_nested_cytoscape_graph_elements, target))

    values = [d['data']['target'] for d in subgraphs if 'target' in d['data'].keys()]
    options = [{'label': i, 'value': i} for i in values]
    return (subgraphs, values, options)

def get_all_the_subsets(condensed_species_nested_cytoscape_graph_elements, target):
    subsets = []
    for d in condensed_species_nested_cytoscape_graph_elements: 
        if 'id' in d['data'].keys():
            if d['data']['id'] == target: subsets.append(d)
        else:
            if d['data']['source'] == target: 
                  subsets.append(d)
                  subsets.append({'data': {'id': d['data']['target'] }})
    return subsets

if __name__ == '__main__':
    app.run_server(debug=True, port=3000)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:3000/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
elements
# Out:
# [{'data': {'id': 'Eukaryota'}},
#  {'data': {'source': 'Eukaryota', 'target': 'Arthropoda', 'weight': 2}},
#  {'data': {'source': 'Eukaryota', 'target': 'Ascomycota', 'weight': 0}},
#  {'data': {'source': 'Eukaryota', 'target': 'Chordata', 'weight': 7}},
#  {'data': {'id': 'Arthropoda'}},
#  {'data': {'source': 'Arthropoda', 'target': 'Insecta', 'weight': 7}},
#  {'data': {'source': 'Arthropoda', 'target': 'Arachnida', 'weight': 1}},
#  {'data': {'id': 'Ascomycota'}},
#  {'data': {'id': 'Chordata'}},
#  {'data': {'source': 'Chordata', 'target': 'Mammalia', 'weight': 20}},
#  {'data': {'source': 'Chordata', 'target': 'Lepidosauria', 'weight': 1}},
#  {'data': {'source': 'Chordata', 'target': 'Aves', 'weight': 32}},
#  {'data': {'source': 'Chordata', 'target': 'Actinopteri', 'weight': 42}},
#  {'data': {'source': 'Chordata', 'target': 'Amphibia', 'weight': 2}},
#  {'data': {'source': 'Chordata', 'target': 'Hyperoartia', 'weight': 1}},
#  {'data': {'source': 'Chordata', 'target': 'Chondrichthyes', 'weight': 6}},
#  {'data': {'id': 'Insecta'}},
#  {'data': {'source': 'Insecta', 'target': 'Coleoptera', 'weight': 6}},
#  {'data': {'source': 'Insecta', 'target': 'Orthoptera', 'weight': 1}},
#  {'data': {'source': 'Insecta', 'target': 'Lepidoptera', 'weight': 14}},
#  {'data': {'source': 'Insecta', 'target': 'Hemiptera', 'weight': 2}},
#  {'data': {'source': 'Insecta', 'target': 'Diptera', 'weight': 5}},
#  {'data': {'source': 'Insecta', 'target': 'Hymenoptera', 'weight': 6}},
#  {'data': {'source': 'Insecta', 'target': 'Blattodea', 'weight': 3}},
#  {'data': {'id': 'Arachnida'}},
#  {'data': {'source': 'Arachnida', 'target': 'Ixodida', 'weight': 1}},
#  {'data': {'id': 'Mammalia'}},
#  {'data': {'source': 'Mammalia', 'target': 'Primates', 'weight': 13}},
#  {'data': {'source': 'Mammalia', 'target': 'Artiodactyla', 'weight': 19}},
#  {'data': {'source': 'Mammalia', 'target': 'Carnivora', 'weight': 14}},
#  {'data': {'source': 'Mammalia', 'target': 'Perissodactyla', 'weight': 3}},
#  {'data': {'source': 'Mammalia', 'target': 'Rodentia', 'weight': 21}},
#  {'data': {'source': 'Mammalia', 'target': 'Lagomorpha', 'weight': 2}},
#  {'data': {'source': 'Mammalia', 'target': 'Proboscidea', 'weight': 1}},
#  {'data': {'source': 'Mammalia', 'target': 'Eulipotyphla', 'weight': 3}},
#  {'data': {'source': 'Mammalia', 'target': 'Cingulata', 'weight': 2}},
#  {'data': {'source': 'Mammalia', 'target': 'Didelphimorphia', 'weight': 1}},
#  {'data': {'source': 'Mammalia', 'target': 'Diprotodontia', 'weight': 7}},
#  {'data': {'source': 'Mammalia', 'target': 'Dasyuromorphia', 'weight': 2}},
#  {'data': {'source': 'Mammalia', 'target': 'Sirenia', 'weight': 1}},
#  {'data': {'source': 'Mammalia', 'target': 'Hyracoidea', 'weight': 1}},
#  {'data': {'source': 'Mammalia', 'target': 'Peramelemorphia', 'weight': 1}},
#  {'data': {'source': 'Mammalia', 'target': 'Chiroptera', 'weight': 11}},
#  {'data': {'source': 'Mammalia', 'target': 'Macroscelidea', 'weight': 1}},
#  {'data': {'source': 'Mammalia', 'target': 'Pilosa', 'weight': 4}},
#  {'data': {'source': 'Mammalia', 'target': 'Monotremata', 'weight': 1}},
#  {'data': {'source': 'Mammalia', 'target': 'Scandentia', 'weight': 1}},
#  {'data': {'id': 'Lepidosauria'}},
#  {'data': {'source': 'Lepidosauria', 'target': 'Squamata', 'weight': 21}},
#  {'data': {'id': 'Aves'}},
#  {'data': {'source': 'Aves', 'target': 'Columbiformes', 'weight': 1}},
#  {'data': {'source': 'Aves', 'target': 'Galliformes', 'weight': 4}},
#  {'data': {'source': 'Aves', 'target': 'Ciconiiformes', 'weight': 1}},
#  {'data': {'source': 'Aves', 'target': 'Accipitriformes', 'weight': 4}},
#  {'data': {'source': 'Aves', 'target': 'Charadriiformes', 'weight': 10}},
#  {'data': {'source': 'Aves', 'target': 'Psittaciformes', 'weight': 3}},
#  {'data': {'source': 'Aves', 'target': 'Sphenisciformes', 'weight': 1}},
#  {'data': {'source': 'Aves', 'target': 'Anseriformes', 'weight': 2}},
#  {'data': {'source': 'Aves', 'target': 'Casuariiformes', 'weight': 1}},
#  {'data': {'source': 'Aves', 'target': 'Coraciiformes', 'weight': 2}},
#  {'data': {'source': 'Aves', 'target': 'Falconiformes', 'weight': 1}},
#  {'data': {'source': 'Aves', 'target': 'Gruiformes', 'weight': 3}},
#  {'data': {'source': 'Aves', 'target': 'Passeriformes', 'weight': 53}},
#  {'data': {'source': 'Aves', 'target': 'Phoenicopteriformes', 'weight': 1}},
#  {'data': {'source': 'Aves', 'target': 'Rheiformes', 'weight': 1}},
#  {'data': {'source': 'Aves', 'target': 'Struthioniformes', 'weight': 1}},
#  {'data': {'source': 'Aves', 'target': 'Trogoniformes', 'weight': 1}},
#  {'data': {'source': 'Aves', 'target': 'Apodiformes', 'weight': 2}},
#  {'data': {'source': 'Aves', 'target': 'Upupiformes', 'weight': 2}},
#  {'data': {'source': 'Aves', 'target': 'Cuculiformes', 'weight': 3}},
#  {'data': {'source': 'Aves', 'target': 'Musophagiformes', 'weight': 1}},
#  {'data': {'source': 'Aves', 'target': 'Pelecaniformes', 'weight': 3}},
#  {'data': {'source': 'Aves', 'target': 'Piciformes', 'weight': 4}},
#  {'data': {'source': 'Aves', 'target': 'Podicipediformes', 'weight': 1}},
#  {'data': {'source': 'Aves', 'target': 'Procellariiformes', 'weight': 2}},
#  {'data': {'source': 'Aves', 'target': 'Strigiformes', 'weight': 2}},
#  {'data': {'source': 'Aves', 'target': 'Apterygiformes', 'weight': 1}},
#  {'data': {'source': 'Aves', 'target': 'Suliformes', 'weight': 3}},
#  {'data': {'source': 'Aves', 'target': 'Gaviiformes', 'weight': 1}},
#  {'data': {'source': 'Aves', 'target': 'Caprimulgiformes', 'weight': 2}},
#  {'data': {'source': 'Aves', 'target': 'Bucerotiformes', 'weight': 2}},
#  {'data': {'source': 'Aves', 'target': 'Galbuliformes', 'weight': 1}},
#  {'data': {'id': 'Actinopteri'}},
#  {'data': {'source': 'Actinopteri',
#    'target': 'Acipenseriformes',
#    'weight': 1}},
#  {'data': {'source': 'Actinopteri', 'target': 'Perciformes', 'weight': 14}},
#  {'data': {'source': 'Actinopteri', 'target': 'Salmoniformes', 'weight': 1}},
#  {'data': {'source': 'Actinopteri', 'target': 'Characiformes', 'weight': 2}},
#  {'data': {'source': 'Actinopteri',
#    'target': 'Cyprinodontiformes',
#    'weight': 3}},
#  {'data': {'source': 'Actinopteri', 'target': 'Cypriniformes', 'weight': 7}},
#  {'data': {'source': 'Actinopteri', 'target': 'Acanthuriformes', 'weight': 2}},
#  {'data': {'source': 'Actinopteri',
#    'target': 'Chaetodontiformes',
#    'weight': 2}},
#  {'data': {'source': 'Actinopteri', 'target': 'Cichliformes', 'weight': 1}},
#  {'data': {'source': 'Actinopteri', 'target': 'Labriformes', 'weight': 1}},
#  {'data': {'source': 'Actinopteri', 'target': 'Spariformes', 'weight': 1}},
#  {'data': {'source': 'Actinopteri',
#    'target': 'Centrarchiformes',
#    'weight': 8}},
#  {'data': {'source': 'Actinopteri',
#    'target': 'Tetraodontiformes',
#    'weight': 4}},
#  {'data': {'source': 'Actinopteri', 'target': 'Gadiformes', 'weight': 6}},
#  {'data': {'source': 'Actinopteri', 'target': 'Anabantiformes', 'weight': 3}},
#  {'data': {'source': 'Actinopteri', 'target': 'Anguilliformes', 'weight': 3}},
#  {'data': {'source': 'Actinopteri', 'target': 'Carangiformes', 'weight': 3}},
#  {'data': {'source': 'Actinopteri', 'target': 'Mugiliformes', 'weight': 1}},
#  {'data': {'source': 'Actinopteri',
#    'target': 'Acropomatiformes',
#    'weight': 2}},
#  {'data': {'source': 'Actinopteri', 'target': 'Lutjaniformes', 'weight': 2}},
#  {'data': {'source': 'Actinopteri',
#    'target': 'Pleuronectiformes',
#    'weight': 7}},
#  {'data': {'source': 'Actinopteri', 'target': 'Siluriformes', 'weight': 6}},
#  {'data': {'source': 'Actinopteri', 'target': 'Osmeriformes', 'weight': 2}},
#  {'data': {'source': 'Actinopteri', 'target': 'Gobiiformes', 'weight': 2}},
#  {'data': {'source': 'Actinopteri', 'target': 'Clupeiformes', 'weight': 2}},
#  {'data': {'source': 'Actinopteri', 'target': 'Scombriformes', 'weight': 2}},
#  {'data': {'source': 'Actinopteri', 'target': 'Aulopiformes', 'weight': 1}},
#  {'data': {'source': 'Actinopteri', 'target': 'Esociformes', 'weight': 1}},
#  {'data': {'source': 'Actinopteri',
#    'target': 'Uranoscopiformes',
#    'weight': 1}},
#  {'data': {'source': 'Actinopteri',
#    'target': 'Osteoglossiformes',
#    'weight': 1}},
#  {'data': {'source': 'Actinopteri',
#    'target': 'Gonorynchiformes',
#    'weight': 1}},
#  {'data': {'source': 'Actinopteri', 'target': 'Argentiniformes', 'weight': 1}},
#  {'data': {'source': 'Actinopteri', 'target': 'Percopsiformes', 'weight': 1}},
#  {'data': {'source': 'Actinopteri', 'target': 'Atheriniformes', 'weight': 1}},
#  {'data': {'source': 'Actinopteri', 'target': 'Syngnathiformes', 'weight': 2}},
#  {'data': {'source': 'Actinopteri', 'target': 'Ophidiiformes', 'weight': 1}},
#  {'data': {'source': 'Actinopteri', 'target': 'Blenniiformes', 'weight': 2}},
#  {'data': {'source': 'Actinopteri', 'target': 'Ephippiformes', 'weight': 1}},
#  {'data': {'source': 'Actinopteri',
#    'target': 'Holocentriformes',
#    'weight': 1}},
#  {'data': {'source': 'Actinopteri', 'target': 'Kurtiformes', 'weight': 1}},
#  {'data': {'source': 'Actinopteri', 'target': 'Lophiiformes', 'weight': 1}},
#  {'data': {'source': 'Actinopteri', 'target': 'Zeiformes', 'weight': 1}},
#  {'data': {'id': 'Amphibia'}},
#  {'data': {'source': 'Amphibia', 'target': 'Anura', 'weight': 15}},
#  {'data': {'source': 'Amphibia', 'target': 'Caudata', 'weight': 6}},
#  {'data': {'id': 'Hyperoartia'}},
#  {'data': {'source': 'Hyperoartia',
#    'target': 'Petromyzontiformes',
#    'weight': 1}},
#  {'data': {'id': 'Chondrichthyes'}},
#  {'data': {'source': 'Chondrichthyes',
#    'target': 'Rhinopristiformes',
#    'weight': 1}},
#  {'data': {'source': 'Chondrichthyes',
#    'target': 'Carcharhiniformes',
#    'weight': 1}},
#  {'data': {'source': 'Chondrichthyes', 'target': 'Lamniformes', 'weight': 1}},
#  {'data': {'source': 'Chondrichthyes', 'target': 'Squaliformes', 'weight': 1}},
#  {'data': {'source': 'Chondrichthyes', 'target': 'Rajiformes', 'weight': 1}},
#  {'data': {'source': 'Chondrichthyes',
#    'target': 'Heterodontiformes',
#    'weight': 1}},
#  {'data': {'id': 'Coleoptera'}},
#  {'data': {'source': 'Coleoptera', 'target': 'Scarabaeidae', 'weight': 17}},
#  {'data': {'source': 'Coleoptera', 'target': 'Curculionidae', 'weight': 7}},
#  {'data': {'source': 'Coleoptera', 'target': 'Chrysomelidae', 'weight': 2}},
#  {'data': {'source': 'Coleoptera', 'target': 'Coccinellidae', 'weight': 1}},
#  {'data': {'source': 'Coleoptera', 'target': 'Tenebrionidae', 'weight': 2}},
#  {'data': {'source': 'Coleoptera', 'target': 'Ptinidae', 'weight': 1}},
#  {'data': {'id': 'Orthoptera'}},
#  {'data': {'source': 'Orthoptera', 'target': 'Acrididae', 'weight': 3}},
#  {'data': {'id': 'Lepidoptera'}},
#  {'data': {'source': 'Lepidoptera', 'target': 'Pyralidae', 'weight': 2}},
#  {'data': {'source': 'Lepidoptera', 'target': 'Noctuidae', 'weight': 7}},
#  {'data': {'source': 'Lepidoptera', 'target': 'Geometridae', 'weight': 4}},
#  {'data': {'source': 'Lepidoptera', 'target': 'Bombycidae', 'weight': 1}},
#  {'data': {'source': 'Lepidoptera', 'target': 'Crambidae', 'weight': 3}},
#  {'data': {'source': 'Lepidoptera', 'target': 'Yponomeutidae', 'weight': 1}},
#  {'data': {'source': 'Lepidoptera', 'target': 'Gelechiidae', 'weight': 1}},
#  {'data': {'source': 'Lepidoptera', 'target': 'Pieridae', 'weight': 2}},
#  {'data': {'source': 'Lepidoptera', 'target': 'Erebidae', 'weight': 2}},
#  {'data': {'source': 'Lepidoptera', 'target': 'Lasiocampidae', 'weight': 1}},
#  {'data': {'source': 'Lepidoptera', 'target': 'Nymphalidae', 'weight': 1}},
#  {'data': {'source': 'Lepidoptera', 'target': 'Tortricidae', 'weight': 2}},
#  {'data': {'source': 'Lepidoptera', 'target': 'Notodontidae', 'weight': 1}},
#  {'data': {'source': 'Lepidoptera', 'target': 'Nolidae', 'weight': 1}},
#  {'data': {'id': 'Hemiptera'}},
#  {'data': {'source': 'Hemiptera', 'target': 'Lygaeidae', 'weight': 1}},
#  {'data': {'source': 'Hemiptera', 'target': 'Aphididae', 'weight': 1}},
#  {'data': {'id': 'Diptera'}},
#  {'data': {'source': 'Diptera', 'target': 'Culicidae', 'weight': 3}},
#  {'data': {'source': 'Diptera', 'target': 'Glossinidae', 'weight': 1}},
#  {'data': {'source': 'Diptera', 'target': 'Tephritidae', 'weight': 1}},
#  {'data': {'source': 'Diptera', 'target': 'Drosophilidae', 'weight': 1}},
#  {'data': {'source': 'Diptera', 'target': 'Simuliidae', 'weight': 1}},
#  {'data': {'id': 'Hymenoptera'}},
#  {'data': {'source': 'Hymenoptera', 'target': 'Diprionidae', 'weight': 3}},
#  {'data': {'source': 'Hymenoptera', 'target': 'Vespidae', 'weight': 1}},
#  {'data': {'source': 'Hymenoptera', 'target': 'Braconidae', 'weight': 1}},
#  {'data': {'source': 'Hymenoptera', 'target': 'Tenthredinidae', 'weight': 2}},
#  {'data': {'source': 'Hymenoptera', 'target': 'Ichneumonidae', 'weight': 1}},
#  {'data': {'source': 'Hymenoptera', 'target': 'Apidae', 'weight': 1}},
#  {'data': {'id': 'Blattodea'}},
#  {'data': {'source': 'Blattodea', 'target': 'Termopsidae', 'weight': 1}},
#  {'data': {'source': 'Blattodea', 'target': 'Blaberidae', 'weight': 1}},
#  {'data': {'source': 'Blattodea', 'target': 'Blattidae', 'weight': 1}},
#  {'data': {'id': 'Ixodida'}},
#  {'data': {'source': 'Ixodida', 'target': 'Ixodidae', 'weight': 1}},
#  {'data': {'id': 'Primates'}},
#  {'data': {'source': 'Primates', 'target': 'Hominidae', 'weight': 4}},
#  {'data': {'source': 'Primates', 'target': 'Lorisidae', 'weight': 3}},
#  {'data': {'source': 'Primates', 'target': 'Cercopithecidae', 'weight': 19}},
#  {'data': {'source': 'Primates', 'target': 'Cebidae', 'weight': 10}},
#  {'data': {'source': 'Primates', 'target': 'Lemuridae', 'weight': 3}},
#  {'data': {'source': 'Primates', 'target': 'Aotidae', 'weight': 1}},
#  {'data': {'source': 'Primates', 'target': 'Hylobatidae', 'weight': 4}},
#  {'data': {'source': 'Primates', 'target': 'Pitheciidae', 'weight': 3}},
#  {'data': {'source': 'Primates', 'target': 'Atelidae', 'weight': 3}},
#  {'data': {'source': 'Primates', 'target': 'Indriidae', 'weight': 2}},
#  {'data': {'source': 'Primates', 'target': 'Cheirogaleidae', 'weight': 2}},
#  {'data': {'source': 'Primates', 'target': 'Galagidae', 'weight': 3}},
#  {'data': {'source': 'Primates', 'target': 'Lepilemuridae', 'weight': 1}},
#  {'data': {'id': 'Artiodactyla'}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Suidae', 'weight': 5}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Bovidae', 'weight': 40}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Camelidae', 'weight': 3}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Phocoenidae', 'weight': 3}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Delphinidae', 'weight': 12}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Cervidae', 'weight': 16}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Giraffidae', 'weight': 2}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Moschidae', 'weight': 1}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Antilocapridae', 'weight': 1}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Monodontidae', 'weight': 1}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Hippopotamidae', 'weight': 2}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Ziphiidae', 'weight': 3}},
#  {'data': {'source': 'Artiodactyla',
#    'target': 'Balaenopteridae',
#    'weight': 1}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Iniidae', 'weight': 1}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Tayassuidae', 'weight': 2}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Physeteridae', 'weight': 1}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Balaenidae', 'weight': 1}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Eschrichtiidae', 'weight': 1}},
#  {'data': {'source': 'Artiodactyla', 'target': 'Tragulidae', 'weight': 1}},
#  {'data': {'id': 'Carnivora'}},
#  {'data': {'source': 'Carnivora', 'target': 'Felidae', 'weight': 12}},
#  {'data': {'source': 'Carnivora', 'target': 'Phocidae', 'weight': 8}},
#  {'data': {'source': 'Carnivora', 'target': 'Mustelidae', 'weight': 14}},
#  {'data': {'source': 'Carnivora', 'target': 'Canidae', 'weight': 10}},
#  {'data': {'source': 'Carnivora', 'target': 'Otariidae', 'weight': 6}},
#  {'data': {'source': 'Carnivora', 'target': 'Mephitidae', 'weight': 2}},
#  {'data': {'source': 'Carnivora', 'target': 'Procyonidae', 'weight': 4}},
#  {'data': {'source': 'Carnivora', 'target': 'Ursidae', 'weight': 4}},
#  {'data': {'source': 'Carnivora', 'target': 'Hyaenidae', 'weight': 3}},
#  {'data': {'source': 'Carnivora', 'target': 'Viverridae', 'weight': 7}},
#  {'data': {'source': 'Carnivora', 'target': 'Herpestidae', 'weight': 7}},
#  {'data': {'source': 'Carnivora', 'target': 'Eupleridae', 'weight': 2}},
#  {'data': {'source': 'Carnivora', 'target': 'Ailuridae', 'weight': 1}},
#  {'data': {'source': 'Carnivora', 'target': 'Odobenidae', 'weight': 1}},
#  {'data': {'id': 'Perissodactyla'}},
#  {'data': {'source': 'Perissodactyla', 'target': 'Equidae', 'weight': 1}},
#  {'data': {'source': 'Perissodactyla',
#    'target': 'Rhinocerotidae',
#    'weight': 3}},
#  {'data': {'source': 'Perissodactyla', 'target': 'Tapiridae', 'weight': 1}},
#  {'data': {'id': 'Rodentia'}},
#  {'data': {'source': 'Rodentia', 'target': 'Cricetidae', 'weight': 46}},
#  {'data': {'source': 'Rodentia', 'target': 'Muridae', 'weight': 40}},
#  {'data': {'source': 'Rodentia', 'target': 'Hydrochaeridae', 'weight': 1}},
#  {'data': {'source': 'Rodentia', 'target': 'Castoridae', 'weight': 1}},
#  {'data': {'source': 'Rodentia', 'target': 'Sciuridae', 'weight': 18}},
#  {'data': {'source': 'Rodentia', 'target': 'Chinchillidae', 'weight': 1}},
#  {'data': {'source': 'Rodentia', 'target': 'Caviidae', 'weight': 1}},
#  {'data': {'source': 'Rodentia', 'target': 'Myocastoridae', 'weight': 1}},
#  {'data': {'source': 'Rodentia', 'target': 'Dipodidae', 'weight': 3}},
#  {'data': {'source': 'Rodentia', 'target': 'Erethizontidae', 'weight': 2}},
#  {'data': {'source': 'Rodentia', 'target': 'Cuniculidae', 'weight': 1}},
#  {'data': {'source': 'Rodentia', 'target': 'Heteromyidae', 'weight': 4}},
#  {'data': {'source': 'Rodentia', 'target': 'Nesomyidae', 'weight': 1}},
#  {'data': {'source': 'Rodentia', 'target': 'Gliridae', 'weight': 2}},
#  {'data': {'source': 'Rodentia', 'target': 'Echimyidae', 'weight': 5}},
#  {'data': {'source': 'Rodentia', 'target': 'Hystricidae', 'weight': 2}},
#  {'data': {'source': 'Rodentia', 'target': 'Pedetidae', 'weight': 1}},
#  {'data': {'source': 'Rodentia', 'target': 'Dasyproctidae', 'weight': 2}},
#  {'data': {'source': 'Rodentia', 'target': 'Geomyidae', 'weight': 2}},
#  {'data': {'source': 'Rodentia', 'target': 'Ctenodactylidae', 'weight': 1}},
#  {'data': {'source': 'Rodentia', 'target': 'Thryonomyidae', 'weight': 1}},
#  {'data': {'id': 'Lagomorpha'}},
#  {'data': {'source': 'Lagomorpha', 'target': 'Leporidae', 'weight': 4}},
#  {'data': {'source': 'Lagomorpha', 'target': 'Ochotonidae', 'weight': 1}},
#  {'data': {'id': 'Proboscidea'}},
#  {'data': {'source': 'Proboscidea', 'target': 'Elephantidae', 'weight': 2}},
#  {'data': {'id': 'Eulipotyphla'}},
#  {'data': {'source': 'Eulipotyphla', 'target': 'Erinaceidae', 'weight': 3}},
#  {'data': {'source': 'Eulipotyphla', 'target': 'Soricidae', 'weight': 6}},
#  {'data': {'source': 'Eulipotyphla', 'target': 'Talpidae', 'weight': 2}},
#  {'data': {'id': 'Cingulata'}},
#  {'data': {'source': 'Cingulata', 'target': 'Dasypodidae', 'weight': 1}},
#  {'data': {'source': 'Cingulata', 'target': 'Chlamyphoridae', 'weight': 1}},
#  {'data': {'id': 'Didelphimorphia'}},
#  {'data': {'source': 'Didelphimorphia', 'target': 'Didelphidae', 'weight': 7}},
#  {'data': {'id': 'Diprotodontia'}},
#  {'data': {'source': 'Diprotodontia', 'target': 'Phalangeridae', 'weight': 1}},
#  {'data': {'source': 'Diprotodontia',
#    'target': 'Phascolarctidae',
#    'weight': 1}},
#  {'data': {'source': 'Diprotodontia', 'target': 'Potoroidae', 'weight': 2}},
#  {'data': {'source': 'Diprotodontia',
#    'target': 'Pseudocheiridae',
#    'weight': 2}},
#  {'data': {'source': 'Diprotodontia', 'target': 'Petauridae', 'weight': 1}},
#  {'data': {'source': 'Diprotodontia', 'target': 'Macropodidae', 'weight': 8}},
#  {'data': {'source': 'Diprotodontia', 'target': 'Vombatidae', 'weight': 1}},
#  {'data': {'id': 'Dasyuromorphia'}},
#  {'data': {'source': 'Dasyuromorphia',
#    'target': 'Myrmecobiidae',
#    'weight': 1}},
#  {'data': {'source': 'Dasyuromorphia', 'target': 'Dasyuridae', 'weight': 2}},
#  {'data': {'id': 'Sirenia'}},
#  {'data': {'source': 'Sirenia', 'target': 'Trichechidae', 'weight': 1}},
#  {'data': {'id': 'Hyracoidea'}},
#  {'data': {'source': 'Hyracoidea', 'target': 'Procaviidae', 'weight': 1}},
#  {'data': {'id': 'Peramelemorphia'}},
#  {'data': {'source': 'Peramelemorphia', 'target': 'Peramelidae', 'weight': 3}},
#  {'data': {'id': 'Chiroptera'}},
#  {'data': {'source': 'Chiroptera', 'target': 'Pteropodidae', 'weight': 12}},
#  {'data': {'source': 'Chiroptera',
#    'target': 'Vespertilionidae',
#    'weight': 25}},
#  {'data': {'source': 'Chiroptera', 'target': 'Phyllostomidae', 'weight': 22}},
#  {'data': {'source': 'Chiroptera', 'target': 'Molossidae', 'weight': 10}},
#  {'data': {'source': 'Chiroptera', 'target': 'Rhinolophidae', 'weight': 1}},
#  {'data': {'source': 'Chiroptera', 'target': 'Hipposideridae', 'weight': 1}},
#  {'data': {'source': 'Chiroptera', 'target': 'Mormoopidae', 'weight': 2}},
#  {'data': {'source': 'Chiroptera', 'target': 'Emballonuridae', 'weight': 3}},
#  {'data': {'source': 'Chiroptera', 'target': 'Nycteridae', 'weight': 1}},
#  {'data': {'source': 'Chiroptera', 'target': 'Megadermatidae', 'weight': 1}},
#  {'data': {'source': 'Chiroptera', 'target': 'Natalidae', 'weight': 1}},
#  {'data': {'id': 'Macroscelidea'}},
#  {'data': {'source': 'Macroscelidea',
#    'target': 'Macroscelididae',
#    'weight': 1}},
#  {'data': {'id': 'Pilosa'}},
#  {'data': {'source': 'Pilosa', 'target': 'Megalonychidae', 'weight': 1}},
#  {'data': {'source': 'Pilosa', 'target': 'Bradypodidae', 'weight': 1}},
#  {'data': {'source': 'Pilosa', 'target': 'Cyclopedidae', 'weight': 1}},
#  {'data': {'source': 'Pilosa', 'target': 'Myrmecophagidae', 'weight': 2}},
#  {'data': {'id': 'Monotremata'}},
#  {'data': {'source': 'Monotremata', 'target': 'Tachyglossidae', 'weight': 1}},
#  {'data': {'id': 'Scandentia'}},
#  {'data': {'source': 'Scandentia', 'target': 'Tupaiidae', 'weight': 1}},
#  {'data': {'id': 'Squamata'}},
#  {'data': {'source': 'Squamata', 'target': 'Agamidae', 'weight': 8}},
#  {'data': {'source': 'Squamata', 'target': 'Pythonidae', 'weight': 3}},
#  {'data': {'source': 'Squamata', 'target': 'Boidae', 'weight': 6}},
#  {'data': {'source': 'Squamata', 'target': 'Chamaeleonidae', 'weight': 3}},
#  {'data': {'source': 'Squamata', 'target': 'Teiidae', 'weight': 2}},
#  {'data': {'source': 'Squamata', 'target': 'Colubridae', 'weight': 18}},
#  {'data': {'source': 'Squamata', 'target': 'Viperidae', 'weight': 11}},
#  {'data': {'source': 'Squamata', 'target': 'Iguanidae', 'weight': 6}},
#  {'data': {'source': 'Squamata', 'target': 'Elapidae', 'weight': 11}},
#  {'data': {'source': 'Squamata', 'target': 'Dipsadidae', 'weight': 2}},
#  {'data': {'source': 'Squamata', 'target': 'Scincidae', 'weight': 5}},
#  {'data': {'source': 'Squamata', 'target': 'Lacertidae', 'weight': 5}},
#  {'data': {'source': 'Squamata', 'target': 'Lamprophiidae', 'weight': 1}},
#  {'data': {'source': 'Squamata', 'target': 'Gekkonidae', 'weight': 3}},
#  {'data': {'source': 'Squamata', 'target': 'Pygopodidae', 'weight': 1}},
#  {'data': {'source': 'Squamata', 'target': 'Varanidae', 'weight': 1}},
#  {'data': {'source': 'Squamata', 'target': 'Eublepharidae', 'weight': 1}},
#  {'data': {'source': 'Squamata', 'target': 'Anguidae', 'weight': 1}},
#  {'data': {'source': 'Squamata', 'target': 'Dactyloidae', 'weight': 1}},
#  {'data': {'source': 'Squamata', 'target': 'Trogonophidae', 'weight': 1}},
#  {'data': {'source': 'Squamata', 'target': 'Xenosauridae', 'weight': 1}},
#  {'data': {'id': 'Columbiformes'}},
#  {'data': {'source': 'Columbiformes', 'target': 'Columbidae', 'weight': 13}},
#  {'data': {'id': 'Galliformes'}},
#  {'data': {'source': 'Galliformes', 'target': 'Phasianidae', 'weight': 21}},
#  {'data': {'source': 'Galliformes', 'target': 'Numididae', 'weight': 1}},
#  {'data': {'source': 'Galliformes', 'target': 'Odontophoridae', 'weight': 2}},
#  {'data': {'source': 'Galliformes', 'target': 'Cracidae', 'weight': 3}},
#  {'data': {'id': 'Ciconiiformes'}},
#  {'data': {'source': 'Ciconiiformes', 'target': 'Ciconiidae', 'weight': 3}},
#  {'data': {'id': 'Accipitriformes'}},
#  {'data': {'source': 'Accipitriformes',
#    'target': 'Accipitridae',
#    'weight': 20}},
#  {'data': {'source': 'Accipitriformes', 'target': 'Cathartidae', 'weight': 3}},
#  {'data': {'source': 'Accipitriformes', 'target': 'Pandionidae', 'weight': 1}},
#  {'data': {'source': 'Accipitriformes',
#    'target': 'Sagittariidae',
#    'weight': 1}},
#  {'data': {'id': 'Charadriiformes'}},
#  {'data': {'source': 'Charadriiformes',
#    'target': 'Recurvirostridae',
#    'weight': 1}},
#  {'data': {'source': 'Charadriiformes', 'target': 'Laridae', 'weight': 12}},
#  {'data': {'source': 'Charadriiformes', 'target': 'Alcidae', 'weight': 2}},
#  {'data': {'source': 'Charadriiformes', 'target': 'Burhinidae', 'weight': 1}},
#  {'data': {'source': 'Charadriiformes',
#    'target': 'Charadriidae',
#    'weight': 6}},
#  {'data': {'source': 'Charadriiformes', 'target': 'Chionididae', 'weight': 1}},
#  {'data': {'source': 'Charadriiformes',
#    'target': 'Scolopacidae',
#    'weight': 11}},
#  {'data': {'source': 'Charadriiformes',
#    'target': 'Stercorariidae',
#    'weight': 1}},
#  {'data': {'source': 'Charadriiformes',
#    'target': 'Haematopodidae',
#    'weight': 1}},
#  {'data': {'source': 'Charadriiformes', 'target': 'Jacanidae', 'weight': 2}},
#  {'data': {'id': 'Psittaciformes'}},
#  {'data': {'source': 'Psittaciformes', 'target': 'Psittacidae', 'weight': 42}},
#  {'data': {'source': 'Psittaciformes',
#    'target': 'Psittaculidae',
#    'weight': 6}},
#  {'data': {'source': 'Psittaciformes', 'target': 'Cacatuidae', 'weight': 5}},
#  {'data': {'id': 'Sphenisciformes'}},
#  {'data': {'source': 'Sphenisciformes',
#    'target': 'Spheniscidae',
#    'weight': 5}},
#  {'data': {'id': 'Anseriformes'}},
#  {'data': {'source': 'Anseriformes', 'target': 'Anatidae', 'weight': 21}},
#  {'data': {'source': 'Anseriformes', 'target': 'Anseranatidae', 'weight': 1}},
#  {'data': {'id': 'Casuariiformes'}},
#  {'data': {'source': 'Casuariiformes', 'target': 'Dromaiidae', 'weight': 1}},
#  {'data': {'id': 'Coraciiformes'}},
#  {'data': {'source': 'Coraciiformes', 'target': 'Alcedinidae', 'weight': 4}},
#  {'data': {'source': 'Coraciiformes', 'target': 'Coraciidae', 'weight': 1}},
#  {'data': {'id': 'Falconiformes'}},
#  {'data': {'source': 'Falconiformes', 'target': 'Falconidae', 'weight': 2}},
#  {'data': {'id': 'Gruiformes'}},
#  {'data': {'source': 'Gruiformes', 'target': 'Gruidae', 'weight': 2}},
#  {'data': {'source': 'Gruiformes', 'target': 'Rallidae', 'weight': 5}},
#  {'data': {'source': 'Gruiformes', 'target': 'Otididae', 'weight': 4}},
#  {'data': {'id': 'Passeriformes'}},
#  {'data': {'source': 'Passeriformes', 'target': 'Corvidae', 'weight': 8}},
#  {'data': {'source': 'Passeriformes', 'target': 'Passeridae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Sturnidae', 'weight': 3}},
#  {'data': {'source': 'Passeriformes', 'target': 'Estrildidae', 'weight': 7}},
#  {'data': {'source': 'Passeriformes', 'target': 'Fringillidae', 'weight': 17}},
#  {'data': {'source': 'Passeriformes', 'target': 'Muscicapidae', 'weight': 6}},
#  {'data': {'source': 'Passeriformes', 'target': 'Icteridae', 'weight': 9}},
#  {'data': {'source': 'Passeriformes', 'target': 'Nectariniidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Acanthizidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Aegithalidae', 'weight': 2}},
#  {'data': {'source': 'Passeriformes', 'target': 'Alaudidae', 'weight': 2}},
#  {'data': {'source': 'Passeriformes', 'target': 'Bombycillidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Passerellidae', 'weight': 9}},
#  {'data': {'source': 'Passeriformes', 'target': 'Eurylaimidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Furnariidae', 'weight': 2}},
#  {'data': {'source': 'Passeriformes', 'target': 'Laniidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes',
#    'target': 'Leiothrichidae',
#    'weight': 2}},
#  {'data': {'source': 'Passeriformes', 'target': 'Maluridae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Meliphagidae', 'weight': 4}},
#  {'data': {'source': 'Passeriformes', 'target': 'Monarchidae', 'weight': 3}},
#  {'data': {'source': 'Passeriformes', 'target': 'Motacillidae', 'weight': 2}},
#  {'data': {'source': 'Passeriformes', 'target': 'Paradisaeidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Paridae', 'weight': 5}},
#  {'data': {'source': 'Passeriformes', 'target': 'Picathartidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Pipridae', 'weight': 2}},
#  {'data': {'source': 'Passeriformes', 'target': 'Ploceidae', 'weight': 2}},
#  {'data': {'source': 'Passeriformes', 'target': 'Thraupidae', 'weight': 7}},
#  {'data': {'source': 'Passeriformes', 'target': 'Turdidae', 'weight': 6}},
#  {'data': {'source': 'Passeriformes', 'target': 'Hirundinidae', 'weight': 5}},
#  {'data': {'source': 'Passeriformes', 'target': 'Cardinalidae', 'weight': 4}},
#  {'data': {'source': 'Passeriformes', 'target': 'Mimidae', 'weight': 3}},
#  {'data': {'source': 'Passeriformes', 'target': 'Tyrannidae', 'weight': 9}},
#  {'data': {'source': 'Passeriformes', 'target': 'Sylviidae', 'weight': 2}},
#  {'data': {'source': 'Passeriformes', 'target': 'Prunellidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Certhiidae', 'weight': 3}},
#  {'data': {'source': 'Passeriformes', 'target': 'Artamidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Sittidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Pycnonotidae', 'weight': 3}},
#  {'data': {'source': 'Passeriformes', 'target': 'Parulidae', 'weight': 5}},
#  {'data': {'source': 'Passeriformes', 'target': 'Vireonidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes',
#    'target': 'Phylloscopidae',
#    'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Pittidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Cotingidae', 'weight': 2}},
#  {'data': {'source': 'Passeriformes', 'target': 'Irenidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Menuridae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes',
#    'target': 'Thamnophilidae',
#    'weight': 4}},
#  {'data': {'source': 'Passeriformes', 'target': 'Formicariidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Prionopidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Timaliidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes',
#    'target': 'Conopophagidae',
#    'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Callaeidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Petroicidae', 'weight': 1}},
#  {'data': {'source': 'Passeriformes', 'target': 'Zosteropidae', 'weight': 1}},
#  {'data': {'id': 'Phoenicopteriformes'}},
#  {'data': {'source': 'Phoenicopteriformes',
#    'target': 'Phoenicopteridae',
#    'weight': 2}},
#  {'data': {'id': 'Rheiformes'}},
#  {'data': {'source': 'Rheiformes', 'target': 'Rheidae', 'weight': 1}},
#  {'data': {'id': 'Struthioniformes'}},
#  {'data': {'source': 'Struthioniformes',
#    'target': 'Struthionidae',
#    'weight': 1}},
#  {'data': {'id': 'Trogoniformes'}},
#  {'data': {'source': 'Trogoniformes', 'target': 'Trogonidae', 'weight': 1}},
#  {'data': {'id': 'Apodiformes'}},
#  {'data': {'source': 'Apodiformes', 'target': 'Trochilidae', 'weight': 2}},
#  {'data': {'source': 'Apodiformes', 'target': 'Apodidae', 'weight': 1}},
#  {'data': {'id': 'Upupiformes'}},
#  {'data': {'source': 'Upupiformes', 'target': 'Phoeniculidae', 'weight': 1}},
#  {'data': {'source': 'Upupiformes', 'target': 'Upupidae', 'weight': 1}},
#  {'data': {'id': 'Cuculiformes'}},
#  {'data': {'source': 'Cuculiformes', 'target': 'Crotophagidae', 'weight': 2}},
#  {'data': {'source': 'Cuculiformes', 'target': 'Centropidae', 'weight': 1}},
#  {'data': {'source': 'Cuculiformes', 'target': 'Cuculidae', 'weight': 1}},
#  {'data': {'id': 'Musophagiformes'}},
#  {'data': {'source': 'Musophagiformes',
#    'target': 'Musophagidae',
#    'weight': 2}},
#  {'data': {'id': 'Pelecaniformes'}},
#  {'data': {'source': 'Pelecaniformes', 'target': 'Ardeidae', 'weight': 8}},
#  {'data': {'source': 'Pelecaniformes', 'target': 'Pelecanidae', 'weight': 1}},
#  {'data': {'source': 'Pelecaniformes',
#    'target': 'Threskiornithidae',
#    'weight': 5}},
#  {'data': {'id': 'Piciformes'}},
#  {'data': {'source': 'Piciformes', 'target': 'Picidae', 'weight': 4}},
#  {'data': {'source': 'Piciformes', 'target': 'Ramphastidae', 'weight': 2}},
#  {'data': {'source': 'Piciformes', 'target': 'Lybiidae', 'weight': 1}},
#  {'data': {'source': 'Piciformes', 'target': 'Megalaimidae', 'weight': 1}},
#  {'data': {'id': 'Podicipediformes'}},
#  {'data': {'source': 'Podicipediformes',
#    'target': 'Podicipedidae',
#    'weight': 4}},
#  {'data': {'id': 'Procellariiformes'}},
#  {'data': {'source': 'Procellariiformes',
#    'target': 'Procellariidae',
#    'weight': 3}},
#  {'data': {'source': 'Procellariiformes',
#    'target': 'Diomedeidae',
#    'weight': 2}},
#  {'data': {'id': 'Strigiformes'}},
#  {'data': {'source': 'Strigiformes', 'target': 'Strigidae', 'weight': 11}},
#  {'data': {'source': 'Strigiformes', 'target': 'Tytonidae', 'weight': 1}},
#  {'data': {'id': 'Apterygiformes'}},
#  {'data': {'source': 'Apterygiformes', 'target': 'Apterygidae', 'weight': 1}},
#  {'data': {'id': 'Suliformes'}},
#  {'data': {'source': 'Suliformes', 'target': 'Anhingidae', 'weight': 1}},
#  {'data': {'source': 'Suliformes',
#    'target': 'Phalacrocoracidae',
#    'weight': 2}},
#  {'data': {'source': 'Suliformes', 'target': 'Sulidae', 'weight': 2}},
#  {'data': {'id': 'Gaviiformes'}},
#  {'data': {'source': 'Gaviiformes', 'target': 'Gaviidae', 'weight': 1}},
#  {'data': {'id': 'Caprimulgiformes'}},
#  {'data': {'source': 'Caprimulgiformes', 'target': 'Podargidae', 'weight': 1}},
#  {'data': {'source': 'Caprimulgiformes',
#    'target': 'Caprimulgidae',
#    'weight': 1}},
#  {'data': {'id': 'Bucerotiformes'}},
#  {'data': {'source': 'Bucerotiformes', 'target': 'Bucorvidae', 'weight': 1}},
#  {'data': {'source': 'Bucerotiformes', 'target': 'Bucerotidae', 'weight': 1}},
#  {'data': {'id': 'Galbuliformes'}},
#  {'data': {'source': 'Galbuliformes', 'target': 'Bucconidae', 'weight': 1}},
#  {'data': {'id': 'Acipenseriformes'}},
#  {'data': {'source': 'Acipenseriformes',
#    'target': 'Acipenseridae',
#    'weight': 1}},
#  {'data': {'id': 'Perciformes'}},
#  {'data': {'source': 'Perciformes', 'target': 'Percidae', 'weight': 2}},
#  {'data': {'source': 'Perciformes', 'target': 'Serranidae', 'weight': 4}},
#  {'data': {'source': 'Perciformes', 'target': 'Cottidae', 'weight': 1}},
#  {'data': {'source': 'Perciformes', 'target': 'Anarhichadidae', 'weight': 1}},
#  {'data': {'source': 'Perciformes', 'target': 'Zoarcidae', 'weight': 1}},
#  {'data': {'source': 'Perciformes', 'target': 'Anoplopomatidae', 'weight': 1}},
#  {'data': {'source': 'Perciformes', 'target': 'Cyclopteridae', 'weight': 1}},
#  {'data': {'source': 'Perciformes', 'target': 'Sebastidae', 'weight': 2}},
#  {'data': {'source': 'Perciformes', 'target': 'Gasterosteidae', 'weight': 1}},
#  {'data': {'source': 'Perciformes', 'target': 'Pholidae', 'weight': 1}},
#  {'data': {'source': 'Perciformes', 'target': 'Aulorhynchidae', 'weight': 1}},
#  {'data': {'source': 'Perciformes', 'target': 'Synanceiidae', 'weight': 1}},
#  {'data': {'source': 'Perciformes', 'target': 'Scorpaenidae', 'weight': 1}},
#  {'data': {'source': 'Perciformes', 'target': 'Triglidae', 'weight': 1}},
#  {'data': {'id': 'Salmoniformes'}},
#  {'data': {'source': 'Salmoniformes', 'target': 'Salmonidae', 'weight': 5}},
#  {'data': {'id': 'Characiformes'}},
#  {'data': {'source': 'Characiformes', 'target': 'Characidae', 'weight': 1}},
#  {'data': {'source': 'Characiformes', 'target': 'Serrasalmidae', 'weight': 2}},
#  {'data': {'id': 'Cyprinodontiformes'}},
#  {'data': {'source': 'Cyprinodontiformes',
#    'target': 'Poeciliidae',
#    'weight': 2}},
#  {'data': {'source': 'Cyprinodontiformes',
#    'target': 'Aphaniidae',
#    'weight': 1}},
#  {'data': {'source': 'Cyprinodontiformes',
#    'target': 'Fundulidae',
#    'weight': 1}},
#  {'data': {'id': 'Cypriniformes'}},
#  {'data': {'source': 'Cypriniformes', 'target': 'Cyprinidae', 'weight': 7}},
#  {'data': {'source': 'Cypriniformes', 'target': 'Tincidae', 'weight': 1}},
#  {'data': {'source': 'Cypriniformes', 'target': 'Leuciscidae', 'weight': 13}},
#  {'data': {'source': 'Cypriniformes',
#    'target': 'Xenocyprididae',
#    'weight': 4}},
#  {'data': {'source': 'Cypriniformes', 'target': 'Danionidae', 'weight': 1}},
#  {'data': {'source': 'Cypriniformes', 'target': 'Gobionidae', 'weight': 2}},
#  {'data': {'source': 'Cypriniformes', 'target': 'Catostomidae', 'weight': 2}},
#  {'data': {'id': 'Acanthuriformes'}},
#  {'data': {'source': 'Acanthuriformes',
#    'target': 'Acanthuridae',
#    'weight': 2}},
#  {'data': {'source': 'Acanthuriformes', 'target': 'Zanclidae', 'weight': 1}},
#  {'data': {'id': 'Chaetodontiformes'}},
#  {'data': {'source': 'Chaetodontiformes',
#    'target': 'Chaetodontidae',
#    'weight': 2}},
#  {'data': {'source': 'Chaetodontiformes',
#    'target': 'Leiognathidae',
#    'weight': 3}},
#  {'data': {'id': 'Cichliformes'}},
#  {'data': {'source': 'Cichliformes', 'target': 'Cichlidae', 'weight': 5}},
#  {'data': {'id': 'Labriformes'}},
#  {'data': {'source': 'Labriformes', 'target': 'Labridae', 'weight': 8}},
#  {'data': {'id': 'Spariformes'}},
#  {'data': {'source': 'Spariformes', 'target': 'Sparidae', 'weight': 10}},
#  {'data': {'id': 'Centrarchiformes'}},
#  {'data': {'source': 'Centrarchiformes',
#    'target': 'Terapontidae',
#    'weight': 3}},
#  {'data': {'source': 'Centrarchiformes',
#    'target': 'Centrarchidae',
#    'weight': 4}},
#  {'data': {'source': 'Centrarchiformes', 'target': 'Latridae', 'weight': 1}},
#  {'data': {'source': 'Centrarchiformes',
#    'target': 'Oplegnathidae',
#    'weight': 1}},
#  {'data': {'source': 'Centrarchiformes', 'target': 'Girellidae', 'weight': 1}},
#  {'data': {'source': 'Centrarchiformes',
#    'target': 'Sinipercidae',
#    'weight': 1}},
#  {'data': {'source': 'Centrarchiformes',
#    'target': 'Percichthyidae',
#    'weight': 1}},
#  {'data': {'source': 'Centrarchiformes', 'target': 'Kyphosidae', 'weight': 1}},
#  {'data': {'id': 'Tetraodontiformes'}},
#  {'data': {'source': 'Tetraodontiformes',
#    'target': 'Diodontidae',
#    'weight': 1}},
#  {'data': {'source': 'Tetraodontiformes',
#    'target': 'Monacanthidae',
#    'weight': 4}},
#  {'data': {'source': 'Tetraodontiformes',
#    'target': 'Tetraodontidae',
#    'weight': 3}},
#  {'data': {'source': 'Tetraodontiformes', 'target': 'Molidae', 'weight': 1}},
#  {'data': {'id': 'Gadiformes'}},
#  {'data': {'source': 'Gadiformes', 'target': 'Gadidae', 'weight': 8}},
#  {'data': {'source': 'Gadiformes', 'target': 'Lotidae', 'weight': 1}},
#  {'data': {'source': 'Gadiformes', 'target': 'Moridae', 'weight': 1}},
#  {'data': {'source': 'Gadiformes', 'target': 'Gaidropsaridae', 'weight': 1}},
#  {'data': {'source': 'Gadiformes', 'target': 'Merlucciidae', 'weight': 1}},
#  {'data': {'source': 'Gadiformes', 'target': 'Macrouridae', 'weight': 1}},
#  {'data': {'id': 'Anabantiformes'}},
#  {'data': {'source': 'Anabantiformes', 'target': 'Channidae', 'weight': 1}},
#  {'data': {'source': 'Anabantiformes', 'target': 'Anabantidae', 'weight': 1}},
#  {'data': {'source': 'Anabantiformes',
#    'target': 'Osphronemidae',
#    'weight': 4}},
#  {'data': {'id': 'Anguilliformes'}},
#  {'data': {'source': 'Anguilliformes', 'target': 'Muraenidae', 'weight': 2}},
#  {'data': {'source': 'Anguilliformes', 'target': 'Anguillidae', 'weight': 1}},
#  {'data': {'source': 'Anguilliformes',
#    'target': 'Muraenesocidae',
#    'weight': 1}},
#  {'data': {'id': 'Carangiformes'}},
#  {'data': {'source': 'Carangiformes', 'target': 'Carangidae', 'weight': 10}},
#  {'data': {'source': 'Carangiformes',
#    'target': 'Rachycentridae',
#    'weight': 1}},
#  {'data': {'source': 'Carangiformes', 'target': 'Coryphaenidae', 'weight': 1}},
#  {'data': {'id': 'Mugiliformes'}},
#  {'data': {'source': 'Mugiliformes', 'target': 'Mugilidae', 'weight': 2}},
#  {'data': {'id': 'Acropomatiformes'}},
#  {'data': {'source': 'Acropomatiformes',
#    'target': 'Lateolabracidae',
#    'weight': 1}},
#  {'data': {'source': 'Acropomatiformes',
#    'target': 'Acropomatidae',
#    'weight': 1}},
#  {'data': {'id': 'Lutjaniformes'}},
#  {'data': {'source': 'Lutjaniformes', 'target': 'Lutjanidae', 'weight': 2}},
#  {'data': {'source': 'Lutjaniformes', 'target': 'Haemulidae', 'weight': 4}},
#  {'data': {'id': 'Pleuronectiformes'}},
#  {'data': {'source': 'Pleuronectiformes',
#    'target': 'Paralichthyidae',
#    'weight': 2}},
#  {'data': {'source': 'Pleuronectiformes',
#    'target': 'Pleuronectidae',
#    'weight': 12}},
#  {'data': {'source': 'Pleuronectiformes',
#    'target': 'Scophthalmidae',
#    'weight': 1}},
#  {'data': {'source': 'Pleuronectiformes',
#    'target': 'Rhombosoleidae',
#    'weight': 1}},
#  {'data': {'source': 'Pleuronectiformes', 'target': 'Soleidae', 'weight': 2}},
#  {'data': {'source': 'Pleuronectiformes', 'target': 'Achiridae', 'weight': 1}},
#  {'data': {'source': 'Pleuronectiformes',
#    'target': 'Cynoglossidae',
#    'weight': 1}},
#  {'data': {'id': 'Siluriformes'}},
#  {'data': {'source': 'Siluriformes', 'target': 'Siluridae', 'weight': 1}},
#  {'data': {'source': 'Siluriformes', 'target': 'Ictaluridae', 'weight': 3}},
#  {'data': {'source': 'Siluriformes', 'target': 'Pimelodidae', 'weight': 1}},
#  {'data': {'source': 'Siluriformes', 'target': 'Plotosidae', 'weight': 1}},
#  {'data': {'source': 'Siluriformes', 'target': 'Clariidae', 'weight': 1}},
#  {'data': {'source': 'Siluriformes', 'target': 'Bagridae', 'weight': 2}},
#  {'data': {'id': 'Osmeriformes'}},
#  {'data': {'source': 'Osmeriformes', 'target': 'Plecoglossidae', 'weight': 1}},
#  {'data': {'source': 'Osmeriformes', 'target': 'Osmeridae', 'weight': 3}},
#  {'data': {'id': 'Gobiiformes'}},
#  {'data': {'source': 'Gobiiformes', 'target': 'Gobiidae', 'weight': 7}},
#  {'data': {'source': 'Gobiiformes', 'target': 'Eleotridae', 'weight': 1}},
#  {'data': {'id': 'Clupeiformes'}},
#  {'data': {'source': 'Clupeiformes', 'target': 'Clupeidae', 'weight': 6}},
#  {'data': {'source': 'Clupeiformes', 'target': 'Engraulidae', 'weight': 2}},
#  {'data': {'id': 'Scombriformes'}},
#  {'data': {'source': 'Scombriformes', 'target': 'Stromateidae', 'weight': 1}},
#  {'data': {'source': 'Scombriformes', 'target': 'Scombridae', 'weight': 1}},
#  {'data': {'id': 'Aulopiformes'}},
#  {'data': {'source': 'Aulopiformes', 'target': 'Synodontidae', 'weight': 2}},
#  {'data': {'id': 'Esociformes'}},
#  {'data': {'source': 'Esociformes', 'target': 'Esocidae', 'weight': 1}},
#  {'data': {'id': 'Uranoscopiformes'}},
#  {'data': {'source': 'Uranoscopiformes',
#    'target': 'Ammodytidae',
#    'weight': 2}},
#  {'data': {'id': 'Osteoglossiformes'}},
#  {'data': {'source': 'Osteoglossiformes',
#    'target': 'Osteoglossidae',
#    'weight': 1}},
#  {'data': {'id': 'Gonorynchiformes'}},
#  {'data': {'source': 'Gonorynchiformes', 'target': 'Chanidae', 'weight': 1}},
#  {'data': {'id': 'Argentiniformes'}},
#  {'data': {'source': 'Argentiniformes',
#    'target': 'Argentinidae',
#    'weight': 1}},
#  {'data': {'id': 'Percopsiformes'}},
#  {'data': {'source': 'Percopsiformes', 'target': 'Percopsidae', 'weight': 1}},
#  {'data': {'id': 'Atheriniformes'}},
#  {'data': {'source': 'Atheriniformes',
#    'target': 'Atherinopsidae',
#    'weight': 1}},
#  {'data': {'id': 'Syngnathiformes'}},
#  {'data': {'source': 'Syngnathiformes', 'target': 'Mullidae', 'weight': 1}},
#  {'data': {'source': 'Syngnathiformes',
#    'target': 'Centriscidae',
#    'weight': 1}},
#  {'data': {'id': 'Ophidiiformes'}},
#  {'data': {'source': 'Ophidiiformes', 'target': 'Ophidiidae', 'weight': 1}},
#  {'data': {'id': 'Blenniiformes'}},
#  {'data': {'source': 'Blenniiformes', 'target': 'Blenniidae', 'weight': 1}},
#  {'data': {'source': 'Blenniiformes', 'target': 'Chaenopsidae', 'weight': 1}},
#  {'data': {'id': 'Ephippiformes'}},
#  {'data': {'source': 'Ephippiformes', 'target': 'Ephippidae', 'weight': 1}},
#  {'data': {'id': 'Holocentriformes'}},
#  {'data': {'source': 'Holocentriformes',
#    'target': 'Holocentridae',
#    'weight': 1}},
#  {'data': {'id': 'Kurtiformes'}},
#  {'data': {'source': 'Kurtiformes', 'target': 'Apogonidae', 'weight': 2}},
#  {'data': {'id': 'Lophiiformes'}},
#  {'data': {'source': 'Lophiiformes', 'target': 'Lophiidae', 'weight': 1}},
#  {'data': {'id': 'Zeiformes'}},
#  {'data': {'source': 'Zeiformes', 'target': 'Zeidae', 'weight': 1}},
#  {'data': {'id': 'Anura'}},
#  {'data': {'source': 'Anura', 'target': 'Pipidae', 'weight': 1}},
#  {'data': {'source': 'Anura', 'target': 'Bufonidae', 'weight': 5}},
#  {'data': {'source': 'Anura', 'target': 'Dicroglossidae', 'weight': 2}},
#  {'data': {'source': 'Anura', 'target': 'Ranidae', 'weight': 3}},
#  {'data': {'source': 'Anura', 'target': 'Limnodynastidae', 'weight': 2}},
#  {'data': {'source': 'Anura', 'target': 'Arthroleptidae', 'weight': 1}},
#  {'data': {'source': 'Anura', 'target': 'Hylidae', 'weight': 5}},
#  {'data': {'source': 'Anura', 'target': 'Ceratophryidae', 'weight': 1}},
#  {'data': {'source': 'Anura', 'target': 'Megophryidae', 'weight': 1}},
#  {'data': {'source': 'Anura', 'target': 'Myobatrachidae', 'weight': 1}},
#  {'data': {'source': 'Anura', 'target': 'Pyxicephalidae', 'weight': 1}},
#  {'data': {'source': 'Anura', 'target': 'Dendrobatidae', 'weight': 3}},
#  {'data': {'source': 'Anura', 'target': 'Alytidae', 'weight': 1}},
#  {'data': {'source': 'Anura', 'target': 'Batrachylidae', 'weight': 1}},
#  {'data': {'source': 'Anura', 'target': 'Craugastoridae', 'weight': 1}},
#  {'data': {'id': 'Caudata'}},
#  {'data': {'source': 'Caudata', 'target': 'Dicamptodontidae', 'weight': 1}},
#  {'data': {'source': 'Caudata', 'target': 'Salamandridae', 'weight': 4}},
#  {'data': {'source': 'Caudata', 'target': 'Ambystomatidae', 'weight': 1}},
#  {'data': {'source': 'Caudata', 'target': 'Hynobiidae', 'weight': 1}},
#  {'data': {'source': 'Caudata', 'target': 'Cryptobranchidae', 'weight': 1}},
#  {'data': {'source': 'Caudata', 'target': 'Plethodontidae', 'weight': 4}},
#  {'data': {'id': 'Petromyzontiformes'}},
#  {'data': {'source': 'Petromyzontiformes',
#    'target': 'Petromyzontidae',
#    'weight': 3}},
#  {'data': {'id': 'Rhinopristiformes'}},
#  {'data': {'source': 'Rhinopristiformes',
#    'target': 'Rhinobatidae',
#    'weight': 1}},
#  {'data': {'id': 'Carcharhiniformes'}},
#  {'data': {'source': 'Carcharhiniformes',
#    'target': 'Carcharhinidae',
#    'weight': 3}},
#  {'data': {'id': 'Lamniformes'}},
#  {'data': {'source': 'Lamniformes', 'target': 'Alopiidae', 'weight': 1}},
#  {'data': {'id': 'Squaliformes'}},
#  {'data': {'source': 'Squaliformes', 'target': 'Squalidae', 'weight': 1}},
#  {'data': {'id': 'Rajiformes'}},
#  {'data': {'source': 'Rajiformes', 'target': 'Rajidae', 'weight': 1}},
#  {'data': {'id': 'Heterodontiformes'}},
#  {'data': {'source': 'Heterodontiformes',
#    'target': 'Heterodontidae',
#    'weight': 1}},
#  {'data': {'id': 'Scarabaeidae'}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Melolontha', 'weight': 0}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Costelytra', 'weight': 0}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Adoryphorus', 'weight': 0}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Phyllopertha', 'weight': 0}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Phyllophaga', 'weight': 2}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Heteronychus', 'weight': 0}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Popillia', 'weight': 0}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Cyclocephala', 'weight': 0}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Maladera', 'weight': 0}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Anoplognathus', 'weight': 0}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Odontria', 'weight': 0}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Cetonia', 'weight': 1}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Sericesthis', 'weight': 0}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Oryctes', 'weight': 0}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Diloboderus', 'weight': 0}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Holotrichia', 'weight': 0}},
#  {'data': {'source': 'Scarabaeidae', 'target': 'Anomala', 'weight': 0}},
#  {'data': {'id': 'Curculionidae'}},
#  {'data': {'source': 'Curculionidae', 'target': 'Dendroctonus', 'weight': 0}},
#  {'data': {'source': 'Curculionidae', 'target': 'Curculio', 'weight': 0}},
#  {'data': {'source': 'Curculionidae', 'target': 'Scolytus', 'weight': 0}},
# ...
#  {'data': {'id': 'Notodontidae'}},
#  {'data': {'source': 'Notodontidae', 'target': 'Thaumetopoea', 'weight': 0}},
#  {'data': {'id': 'Nolidae'}},
#  {'data': {'source': 'Nolidae', 'target': 'Eligma', 'weight': 0}},
#  {'data': {'id': 'Lygaeidae'}},
#  {'data': {'source': 'Lygaeidae', 'target': 'Oncopeltus', 'weight': 0}},
#  {'data': {'id': 'Aphididae'}},
#  {'data': {'source': 'Aphididae', 'target': 'Aulacorthum', 'weight': 0}},
#  {'data': {'id': 'Culicidae'}},
#  {'data': {'source': 'Culicidae', 'target': 'Aedes', 'weight': 1}},
#  {'data': {'source': 'Culicidae', 'target': 'Anopheles', 'weight': 0}},
#  {'data': {'source': 'Culicidae', 'target': 'Culex', 'weight': 1}},
#  {'data': {'id': 'Glossinidae'}},
#  {'data': {'source': 'Glossinidae', 'target': 'Glossina', 'weight': 1}},
#  {'data': {'id': 'Tephritidae'}},
#  {'data': {'source': 'Tephritidae', 'target': 'Anastrepha', 'weight': 0}},
#  {'data': {'id': 'Drosophilidae'}},
#  {'data': {'source': 'Drosophilidae', 'target': 'Drosophila', 'weight': 0}},
#  {'data': {'id': 'Simuliidae'}},
#  {'data': {'source': 'Simuliidae', 'target': 'Simulium', 'weight': 0}},
#  {'data': {'id': 'Diprionidae'}},
#  {'data': {'source': 'Diprionidae', 'target': 'Diprion', 'weight': 0}},
#  {'data': {'source': 'Diprionidae', 'target': 'Neodiprion', 'weight': 1}},
#  {'data': {'source': 'Diprionidae', 'target': 'Gilpinia', 'weight': 0}},
#  {'data': {'id': 'Vespidae'}},
#  {'data': {'source': 'Vespidae', 'target': 'Vespula', 'weight': 0}},
#  {'data': {'id': 'Braconidae'}},
#  {'data': {'source': 'Braconidae', 'target': 'Microplitis', 'weight': 0}},
#  {'data': {'id': 'Tenthredinidae'}},
#  {'data': {'source': 'Tenthredinidae', 'target': 'Pristiphora', 'weight': 0}},
#  {'data': {'source': 'Tenthredinidae', 'target': 'Hemichroa', 'weight': 0}},
#  {'data': {'id': 'Ichneumonidae'}},
#  {'data': {'source': 'Ichneumonidae', 'target': 'Exeristes', 'weight': 0}},
#  {'data': {'id': 'Apidae'}},
#  {'data': {'source': 'Apidae', 'target': 'Apis', 'weight': 1}},
#  {'data': {'id': 'Termopsidae'}},
#  {'data': {'source': 'Termopsidae', 'target': 'Zootermopsis', 'weight': 0}},
#  {'data': {'id': 'Blaberidae'}},
#  {'data': {'source': 'Blaberidae', 'target': 'Blaberus', 'weight': 0}},
#  {'data': {'id': 'Blattidae'}},
#  {'data': {'source': 'Blattidae', 'target': 'Periplaneta', 'weight': 0}},
#  {'data': {'id': 'Ixodidae'}},
#  {'data': {'source': 'Ixodidae', 'target': 'Dermacentor', 'weight': 0}},
#  {'data': {'id': 'Hominidae'}},
#  {'data': {'source': 'Hominidae', 'target': 'Homo', 'weight': 0}},
#  {'data': {'source': 'Hominidae', 'target': 'Gorilla', 'weight': 1}},
#  {'data': {'source': 'Hominidae', 'target': 'Pan', 'weight': 0}},
#  {'data': {'source': 'Hominidae', 'target': 'Pongo', 'weight': 0}},
#  {'data': {'id': 'Lorisidae'}},
#  {'data': {'source': 'Lorisidae', 'target': 'Loris', 'weight': 0}},
#  {'data': {'source': 'Lorisidae', 'target': 'Nycticebus', 'weight': 0}},
#  {'data': {'source': 'Lorisidae', 'target': 'Perodicticus', 'weight': 0}},
#  {'data': {'id': 'Cercopithecidae'}},
#  {'data': {'source': 'Cercopithecidae', 'target': 'Macaca', 'weight': 0}},
#  {'data': {'source': 'Cercopithecidae', 'target': 'Papio', 'weight': 0}},
#  {'data': {'source': 'Cercopithecidae',
#    'target': 'Cercopithecus',
#    'weight': 0}},
#  {'data': {'source': 'Cercopithecidae', 'target': 'Cercocebus', 'weight': 0}},
#  {'data': {'source': 'Cercopithecidae',
#    'target': 'Erythrocebus',
#    'weight': 0}},
#  {'data': {'source': 'Cercopithecidae', 'target': 'Chlorocebus', 'weight': 0}},
#  {'data': {'source': 'Cercopithecidae', 'target': 'Presbytis', 'weight': 0}},
#  {'data': {'source': 'Cercopithecidae', 'target': 'Colobus', 'weight': 0}},
#  {'data': {'source': 'Cercopithecidae',
#    'target': 'Trachypithecus',
#    'weight': 0}},
#  {'data': {'source': 'Cercopithecidae', 'target': 'Lophocebus', 'weight': 0}},
#  {'data': {'source': 'Cercopithecidae', 'target': 'Mandrillus', 'weight': 0}},
#  {'data': {'source': 'Cercopithecidae', 'target': 'Miopithecus', 'weight': 0}},
#  {'data': {'source': 'Cercopithecidae',
#    'target': 'Semnopithecus',
#    'weight': 0}},
#  {'data': {'source': 'Cercopithecidae',
#    'target': 'Piliocolobus',
#    'weight': 0}},
#  {'data': {'source': 'Cercopithecidae',
#    'target': 'Rhinopithecus',
#    'weight': 0}},
#  {'data': {'source': 'Cercopithecidae', 'target': 'Pygathrix', 'weight': 0}},
#  {'data': {'source': 'Cercopithecidae',
#    'target': 'Allenopithecus',
#    'weight': 0}},
#  {'data': {'source': 'Cercopithecidae',
#    'target': 'Theropithecus',
#    'weight': 0}},
#  {'data': {'source': 'Cercopithecidae', 'target': 'Procolobus', 'weight': 0}},
#  {'data': {'id': 'Cebidae'}},
#  {'data': {'source': 'Cebidae', 'target': 'Callithrix', 'weight': 0}},
#  {'data': {'source': 'Cebidae', 'target': 'Saguinus', 'weight': 0}},
#  {'data': {'source': 'Cebidae', 'target': 'Saimiri', 'weight': 0}},
#  {'data': {'source': 'Cebidae', 'target': 'Callimico', 'weight': 0}},
#  {'data': {'source': 'Cebidae', 'target': 'Leontocebus', 'weight': 0}},
#  {'data': {'source': 'Cebidae', 'target': 'Sapajus', 'weight': 0}},
#  {'data': {'source': 'Cebidae', 'target': 'Leontopithecus', 'weight': 0}},
#  {'data': {'source': 'Cebidae', 'target': 'Mico', 'weight': 0}},
#  {'data': {'source': 'Cebidae', 'target': 'Cebus', 'weight': 0}},
#  {'data': {'source': 'Cebidae', 'target': 'Cebuella', 'weight': 0}},
#  {'data': {'id': 'Lemuridae'}},
#  {'data': {'source': 'Lemuridae', 'target': 'Lemur', 'weight': 0}},
#  {'data': {'source': 'Lemuridae', 'target': 'Eulemur', 'weight': 0}},
#  {'data': {'source': 'Lemuridae', 'target': 'Varecia', 'weight': 0}},
#  {'data': {'id': 'Aotidae'}},
#  {'data': {'source': 'Aotidae', 'target': 'Aotus', 'weight': 0}},
#  {'data': {'id': 'Hylobatidae'}},
#  {'data': {'source': 'Hylobatidae', 'target': 'Symphalangus', 'weight': 0}},
#  {'data': {'source': 'Hylobatidae', 'target': 'Hylobates', 'weight': 0}},
#  {'data': {'source': 'Hylobatidae', 'target': 'Nomascus', 'weight': 0}},
#  {'data': {'source': 'Hylobatidae', 'target': 'Hoolock', 'weight': 0}},
#  {'data': {'id': 'Pitheciidae'}},
#  {'data': {'source': 'Pitheciidae', 'target': 'Chiropotes', 'weight': 0}},
#  {'data': {'source': 'Pitheciidae', 'target': 'Pithecia', 'weight': 0}},
#  {'data': {'source': 'Pitheciidae', 'target': 'Cacajao', 'weight': 0}},
#  {'data': {'id': 'Atelidae'}},
#  {'data': {'source': 'Atelidae', 'target': 'Ateles', 'weight': 0}},
#  {'data': {'source': 'Atelidae', 'target': 'Brachyteles', 'weight': 0}},
#  {'data': {'source': 'Atelidae', 'target': 'Alouatta', 'weight': 0}},
#  {'data': {'id': 'Indriidae'}},
#  {'data': {'source': 'Indriidae', 'target': 'Propithecus', 'weight': 0}},
#  {'data': {'source': 'Indriidae', 'target': 'Indri', 'weight': 0}},
#  {'data': {'id': 'Cheirogaleidae'}},
#  {'data': {'source': 'Cheirogaleidae', 'target': 'Cheirogaleus', 'weight': 0}},
#  {'data': {'source': 'Cheirogaleidae', 'target': 'Phaner', 'weight': 0}},
#  {'data': {'id': 'Galagidae'}},
#  {'data': {'source': 'Galagidae', 'target': 'Galago', 'weight': 0}},
#  {'data': {'source': 'Galagidae', 'target': 'Galagoides', 'weight': 0}},
#  {'data': {'source': 'Galagidae', 'target': 'Otolemur', 'weight': 0}},
#  {'data': {'id': 'Lepilemuridae'}},
#  {'data': {'source': 'Lepilemuridae', 'target': 'Lepilemur', 'weight': 0}},
#  {'data': {'id': 'Suidae'}},
#  {'data': {'source': 'Suidae', 'target': 'Sus', 'weight': 1}},
#  {'data': {'source': 'Suidae', 'target': 'Phacochoerus', 'weight': 0}},
#  {'data': {'source': 'Suidae', 'target': 'Potamochoerus', 'weight': 0}},
#  {'data': {'source': 'Suidae', 'target': 'Babyrousa', 'weight': 0}},
#  {'data': {'source': 'Suidae', 'target': 'Hylochoerus', 'weight': 0}},
#  {'data': {'id': 'Bovidae'}},
#  {'data': {'source': 'Bovidae', 'target': 'Ovis', 'weight': 1}},
#  {'data': {'source': 'Bovidae', 'target': 'Bos', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Capra', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Antilope', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Cephalophus', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Connochaetes', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Gazella', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Oryx', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Bison', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Rupicapra', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Bubalus', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Tragelaphus', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Oreamnos', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Aepyceros', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Damaliscus', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Kobus', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Syncerus', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Budorcas', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Ammotragus', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Antidorcas', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Alcelaphus', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Hippotragus', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Oreotragus', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Raphicerus', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Redunca', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Sylvicapra', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Ovibos', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Philantomba', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Capricornis', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Pseudois', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Nanger', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Litocranius', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Boselaphus', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Ourebia', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Hemitragus', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Procapra', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Saiga', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Madoqua', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Beatragus', 'weight': 0}},
#  {'data': {'source': 'Bovidae', 'target': 'Addax', 'weight': 0}},
#  {'data': {'id': 'Camelidae'}},
#  {'data': {'source': 'Camelidae', 'target': 'Lama', 'weight': 0}},
#  {'data': {'source': 'Camelidae', 'target': 'Camelus', 'weight': 0}},
#  {'data': {'source': 'Camelidae', 'target': 'Vicugna', 'weight': 0}},
#  {'data': {'id': 'Phocoenidae'}},
#  {'data': {'source': 'Phocoenidae', 'target': 'Phocoena', 'weight': 0}},
#  {'data': {'source': 'Phocoenidae', 'target': 'Neophocaena', 'weight': 0}},
#  {'data': {'source': 'Phocoenidae', 'target': 'Phocoenoides', 'weight': 0}},
#  {'data': {'id': 'Delphinidae'}},
#  {'data': {'source': 'Delphinidae', 'target': 'Delphinus', 'weight': 0}},
#  {'data': {'source': 'Delphinidae', 'target': 'Orcinus', 'weight': 0}},
#  {'data': {'source': 'Delphinidae', 'target': 'Globicephala', 'weight': 0}},
#  {'data': {'source': 'Delphinidae', 'target': 'Stenella', 'weight': 0}},
#  {'data': {'source': 'Delphinidae', 'target': 'Lagenorhynchus', 'weight': 0}},
#  {'data': {'source': 'Delphinidae', 'target': 'Pseudorca', 'weight': 0}},
#  {'data': {'source': 'Delphinidae', 'target': 'Grampus', 'weight': 0}},
#  {'data': {'source': 'Delphinidae', 'target': 'Feresa', 'weight': 0}},
#  {'data': {'source': 'Delphinidae', 'target': 'Lagenodelphis', 'weight': 0}},
#  {'data': {'source': 'Delphinidae', 'target': 'Peponocephala', 'weight': 0}},
#  {'data': {'source': 'Delphinidae', 'target': 'Sotalia', 'weight': 0}},
#  {'data': {'source': 'Delphinidae', 'target': 'Tursiops', 'weight': 0}},
#  {'data': {'id': 'Cervidae'}},
#  {'data': {'source': 'Cervidae', 'target': 'Dama', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Muntiacus', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Cervus', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Odocoileus', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Pudu', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Capreolus', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Alces', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Axis', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Rusa', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Hydropotes', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Blastocerus', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Ozotoceros', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Elaphurus', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Rucervus', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Mazama', 'weight': 0}},
#  {'data': {'source': 'Cervidae', 'target': 'Elaphodus', 'weight': 0}},
#  {'data': {'id': 'Giraffidae'}},
#  {'data': {'source': 'Giraffidae', 'target': 'Giraffa', 'weight': 0}},
#  {'data': {'source': 'Giraffidae', 'target': 'Okapia', 'weight': 0}},
#  {'data': {'id': 'Moschidae'}},
#  {'data': {'source': 'Moschidae', 'target': 'Moschus', 'weight': 0}},
#  {'data': {'id': 'Antilocapridae'}},
#  {'data': {'source': 'Antilocapridae', 'target': 'Antilocapra', 'weight': 0}},
#  {'data': {'id': 'Monodontidae'}},
#  {'data': {'source': 'Monodontidae', 'target': 'Delphinapterus', 'weight': 0}},
#  {'data': {'id': 'Hippopotamidae'}},
#  {'data': {'source': 'Hippopotamidae', 'target': 'Hexaprotodon', 'weight': 0}},
#  {'data': {'source': 'Hippopotamidae', 'target': 'Hippopotamus', 'weight': 0}},
#  {'data': {'id': 'Ziphiidae'}},
#  {'data': {'source': 'Ziphiidae', 'target': 'Ziphius', 'weight': 0}},
#  {'data': {'source': 'Ziphiidae', 'target': 'Mesoplodon', 'weight': 0}},
#  {'data': {'source': 'Ziphiidae', 'target': 'Indopacetus', 'weight': 0}},
#  {'data': {'id': 'Balaenopteridae'}},
#  {'data': {'source': 'Balaenopteridae',
#    'target': 'Balaenoptera',
#    'weight': 0}},
#  {'data': {'id': 'Iniidae'}},
#  {'data': {'source': 'Iniidae', 'target': 'Inia', 'weight': 0}},
#  {'data': {'id': 'Tayassuidae'}},
#  {'data': {'source': 'Tayassuidae', 'target': 'Pecari', 'weight': 0}},
#  {'data': {'source': 'Tayassuidae', 'target': 'Tayassu', 'weight': 0}},
#  {'data': {'id': 'Physeteridae'}},
#  {'data': {'source': 'Physeteridae', 'target': 'Kogia', 'weight': 0}},
#  {'data': {'id': 'Balaenidae'}},
#  {'data': {'source': 'Balaenidae', 'target': 'Balaena', 'weight': 0}},
#  {'data': {'id': 'Eschrichtiidae'}},
#  {'data': {'source': 'Eschrichtiidae', 'target': 'Eschrichtius', 'weight': 0}},
#  {'data': {'id': 'Tragulidae'}},
#  {'data': {'source': 'Tragulidae', 'target': 'Tragulus', 'weight': 0}},
#  {'data': {'id': 'Felidae'}},
#  {'data': {'source': 'Felidae', 'target': 'Felis', 'weight': 0}},
#  {'data': {'source': 'Felidae', 'target': 'Panthera', 'weight': 0}},
#  {'data': {'source': 'Felidae', 'target': 'Acinonyx', 'weight': 0}},
#  {'data': {'source': 'Felidae', 'target': 'Lynx', 'weight': 0}},
#  {'data': {'source': 'Felidae', 'target': 'Caracal', 'weight': 0}},
#  {'data': {'source': 'Felidae', 'target': 'Catopuma', 'weight': 0}},
#  {'data': {'source': 'Felidae', 'target': 'Leopardus', 'weight': 0}},
#  {'data': {'source': 'Felidae', 'target': 'Neofelis', 'weight': 0}},
#  {'data': {'source': 'Felidae', 'target': 'Prionailurus', 'weight': 0}},
#  {'data': {'source': 'Felidae', 'target': 'Profelis', 'weight': 0}},
#  {'data': {'source': 'Felidae', 'target': 'Puma', 'weight': 0}},
#  {'data': {'source': 'Felidae', 'target': 'Leptailurus', 'weight': 0}},
#  {'data': {'id': 'Phocidae'}},
#  {'data': {'source': 'Phocidae', 'target': 'Cystophora', 'weight': 0}},
#  {'data': {'source': 'Phocidae', 'target': 'Halichoerus', 'weight': 0}},
#  {'data': {'source': 'Phocidae', 'target': 'Mirounga', 'weight': 0}},
#  {'data': {'source': 'Phocidae', 'target': 'Phoca', 'weight': 0}},
#  {'data': {'source': 'Phocidae', 'target': 'Pusa', 'weight': 0}},
#  {'data': {'source': 'Phocidae', 'target': 'Erignathus', 'weight': 0}},
#  ...]
